# %% [markdown]
# # ASAP warnings
#
# <!-- markdownlint-disable MD013 -->

# %%
# %load_ext jupyter_black
# %load_ext autoreload
# %autoreload 2
# Out:
# The jupyter_black extension is already loaded. To reload it, use:
#   %reload_ext jupyter_black
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import calendar
import re

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import seaborn as sns

from src.constants import *
from src.datasources import asap, seas5
from src.utils import dekad, blob_utils, rp_calc

# %%
asap.process_asap_warnings()

# %% [markdown]
# ## Load pre-filtered data
#
# And do some light processing

# %%
df_asap = asap.load_processed_asap_warnings()

# %%
def get_alert_gr_int(alert_gr_str):
    str_prefix_removed = alert_gr_str.removeprefix("Warning group ")
    try:
        return int(str_prefix_removed)
    except ValueError:
        return 0


for crop_range in ["crop", "range"]:
    df_asap[f"w_{crop_range}_gr_int"] = df_asap[f"w_{crop_range}_gr"].apply(
        get_alert_gr_int
    )

df_asap["year"] = df_asap["date"].dt.year
df_asap = df_asap[df_asap["year"] <= 2025].copy()

# %%
df_asap[
    [x for x in df_asap.columns if "w_crop" in x]
].drop_duplicates().sort_values("w_crop")
# Out:
#          w_crop                                     w_crop_na  \
# 189423        0                                    No warning
# 374127        2                               Warning level 1
# 376497        3                               Warning level 1
# 483047        4                              Warning level 1+
# 120751        5                               Warning level 2
# 483057        6                               Warning level 3
# 142063        7                               Warning level 3
# 909295        8                              Warning level 3+
# 542247        9                               Warning level 4
# 33135        10        No warning with exceptional conditions
# 378859       12   Warning level 1 with exceptional conditions
# 729319       13   Warning level 1 with exceptional conditions
# 1851759      14  Warning level 1+ with exceptional conditions
# 118383       15   Warning level 2 with exceptional conditions
# 18927        20                             Successful season
# 16551        98                                    Off season
#
#                                                  w_crop_de        w_crop_gr  \
# 189423   Season is active but no relevant anomalies are...       No warning
# 374127   At least 25% of the active area is affected by...  Warning group 1
# 376497   At least 25% of the active area is affected by...  Warning group 1
# 483047   At least 25% of the active area is affected by...  Warning group 1
# 120751   At least 25% of the active area is affected by...  Warning group 2
# 483057   At least 25% of the active area is affected by...  Warning group 3
# 142063   At least 25% of the active area is affected by...  Warning group 3
# 909295   At least 25% of the active area is affected by...  Warning group 3
# 542247   Season is in the senescence stage with at leas...  Warning group 4
# 33135    Season is active but no relevant negative anom...       No warning
# 378859   At least 25% of the active area is affected by...  Warning group 1
# 729319   At least 25% of the active area is affected by...  Warning group 1
# 1851759  At least 25% of the active area is affected by...  Warning group 1
# 118383   At least 25% of the active area is affected by...  Warning group 2
# 18927    Season is in the senescence stage with at leas...       No warning
# 16551    Less than 15% of tatal area is active (over al...       Off season
#
#          w_crop_gr_int
# 189423               0
# 374127               1
# 376497               1
# 483047               1
# 120751               2
# 483057               3
# 142063               3
# 909295               3
# 542247               4
# 33135                0
# 378859               1
# 729319               1
# 1851759              1
# 118383               2
# 18927                0
# 16551                0

# %% [markdown]
# Check that the "Warning with exceptional conditions" don't happen too often - looks fine.

# %%
df_asap["w_crop"].value_counts().plot.bar()
# Out:
# <Axes: xlabel='w_crop'>

# %%
all_years = df_asap["date"].dt.year.unique()

# %%
all_years
# Out:
# array([2025, 2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015,
#        2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004,
#        2003, 2002, 2001], dtype=int32)

# %% [markdown]
# ## Cycle through ASAP warning options
#
# There's various ways to combine the warnings, but I broke it down to:
#
# - either `OR` or `AND` condition to combine crop and range
# - minimum number of admin1s with the alert level
# - minimum alert level

# %%
# options

crop_range_options = ["OR", "AND"]
minimum_adm1s_options = [1, 2, 3, 4]
alert_level_options = [1, 2, 3, 4]

# %%
# set first possible trigger dekad to 3rd dekad of July
min_dekad = 21
# set last possible trigger dekad to 3rd dekad of Sep
max_dekad = 27

df_monitoring = df_asap[
    (df_asap["dekad"] >= min_dekad) & (df_asap["dekad"] <= max_dekad)
]

dfs = []
for crop_range in crop_range_options:
    for minimum_adm1s in minimum_adm1s_options:
        for alert_level in alert_level_options:
            dff = df_monitoring.copy()
            if crop_range == "OR":
                dff["indicator"] = dff[
                    ["w_crop_gr_int", "w_range_gr_int"]
                ].max(axis=1)
            elif crop_range == "AND":
                dff["indicator"] = dff[
                    ["w_crop_gr_int", "w_range_gr_int"]
                ].min(axis=1)
            else:
                raise ValueError("invalid crop_range")
            dff = dff[dff["indicator"] >= alert_level]
            adm_counts = (
                dff.groupby("year")
                .agg(
                    count_adm1s=("ADM1_PCODE", "nunique"),
                    min_dekad=("dekad", "min"),
                )
                .reset_index()
            )
            display(adm_counts)
            trigger_years = adm_counts[
                adm_counts["count_adm1s"] >= minimum_adm1s
            ][["year", "min_dekad"]]
            trigger_years[["crop_range", "minadm1s", "al"]] = (
                crop_range,
                minimum_adm1s,
                alert_level,
            )
            dfs.append(trigger_years)

df_triggers = pd.concat(dfs, ignore_index=True)
# Out:
#     year  count_adm1s  min_dekad
# 0   2001            3         26
# 1   2002            4         21
# 2   2004            4         21
# 3   2005            3         21
# 4   2006            4         21
# 5   2007            3         21
# 6   2008            2         21
# 7   2009            2         21
# 8   2010            2         21
# 9   2011            4         21
# 10  2013            1         21
# 11  2014            3         22
# 12  2015            3         21
# 13  2016            1         25
# 14  2017            2         23
# 15  2019            3         21
# 16  2020            3         21
# 17  2021            3         24
# 18  2023            1         21
# 19  2024            3         21
#     year  count_adm1s  min_dekad
# 0   2001            1         26
# 1   2002            4         21
# 2   2004            2         21
# 3   2006            4         21
# 4   2009            2         21
# 5   2010            2         21
# 6   2011            3         21
# 7   2014            1         24
# 8   2015            3         21
# 9   2019            3         21
# 10  2020            2         21
# 11  2023            1         21
# 12  2024            2         21
#    year  count_adm1s  min_dekad
# 0  2002            4         21
# 1  2004            2         22
# 2  2006            3         21
# 3  2009            2         21
# 4  2010            1         21
# 5  2011            1         21
# 6  2014            1         24
# 7  2015            1         21
# 8  2019            1         27
# 9  2024            1         21
# Empty DataFrame
# Columns: [year, count_adm1s, min_dekad]
# Index: []
#     year  count_adm1s  min_dekad
# 0   2001            3         26
# 1   2002            4         21
# 2   2004            4         21
# 3   2005            3         21
# 4   2006            4         21
# 5   2007            3         21
# 6   2008            2         21
# 7   2009            2         21
# 8   2010            2         21
# 9   2011            4         21
# 10  2013            1         21
# 11  2014            3         22
# 12  2015            3         21
# 13  2016            1         25
# 14  2017            2         23
# 15  2019            3         21
# 16  2020            3         21
# 17  2021            3         24
# 18  2023            1         21
# 19  2024            3         21
#     year  count_adm1s  min_dekad
# 0   2001            1         26
# 1   2002            4         21
# 2   2004            2         21
# 3   2006            4         21
# 4   2009            2         21
# 5   2010            2         21
# 6   2011            3         21
# 7   2014            1         24
# 8   2015            3         21
# 9   2019            3         21
# 10  2020            2         21
# 11  2023            1         21
# 12  2024            2         21
#    year  count_adm1s  min_dekad
# 0  2002            4         21
# 1  2004            2         22
# 2  2006            3         21
# 3  2009            2         21
# 4  2010            1         21
# 5  2011            1         21
# 6  2014            1         24
# 7  2015            1         21
# 8  2019            1         27
# 9  2024            1         21
# Empty DataFrame
# Columns: [year, count_adm1s, min_dekad]
# Index: []
#     year  count_adm1s  min_dekad
# 0   2001            3         26
# 1   2002            4         21
# 2   2004            4         21
# 3   2005            3         21
# 4   2006            4         21
# 5   2007            3         21
# 6   2008            2         21
# 7   2009            2         21
# 8   2010            2         21
# 9   2011            4         21
# 10  2013            1         21
# 11  2014            3         22
# 12  2015            3         21
# 13  2016            1         25
# 14  2017            2         23
# 15  2019            3         21
# 16  2020            3         21
# 17  2021            3         24
# 18  2023            1         21
# 19  2024            3         21
#     year  count_adm1s  min_dekad
# 0   2001            1         26
# 1   2002            4         21
# 2   2004            2         21
# 3   2006            4         21
# 4   2009            2         21
# 5   2010            2         21
# 6   2011            3         21
# 7   2014            1         24
# 8   2015            3         21
# 9   2019            3         21
# 10  2020            2         21
# 11  2023            1         21
# 12  2024            2         21
#    year  count_adm1s  min_dekad
# 0  2002            4         21
# 1  2004            2         22
# 2  2006            3         21
# 3  2009            2         21
# 4  2010            1         21
# 5  2011            1         21
# 6  2014            1         24
# 7  2015            1         21
# 8  2019            1         27
# 9  2024            1         21
# Empty DataFrame
# Columns: [year, count_adm1s, min_dekad]
# Index: []
#     year  count_adm1s  min_dekad
# 0   2001            3         26
# 1   2002            4         21
# 2   2004            4         21
# 3   2005            3         21
# 4   2006            4         21
# 5   2007            3         21
# 6   2008            2         21
# 7   2009            2         21
# 8   2010            2         21
# 9   2011            4         21
# 10  2013            1         21
# 11  2014            3         22
# 12  2015            3         21
# 13  2016            1         25
# 14  2017            2         23
# 15  2019            3         21
# 16  2020            3         21
# 17  2021            3         24
# 18  2023            1         21
# 19  2024            3         21
#     year  count_adm1s  min_dekad
# 0   2001            1         26
# 1   2002            4         21
# 2   2004            2         21
# 3   2006            4         21
# 4   2009            2         21
# 5   2010            2         21
# 6   2011            3         21
# 7   2014            1         24
# 8   2015            3         21
# 9   2019            3         21
# 10  2020            2         21
# 11  2023            1         21
# 12  2024            2         21
#    year  count_adm1s  min_dekad
# 0  2002            4         21
# 1  2004            2         22
# 2  2006            3         21
# 3  2009            2         21
# 4  2010            1         21
# 5  2011            1         21
# 6  2014            1         24
# 7  2015            1         21
# 8  2019            1         27
# 9  2024            1         21
# Empty DataFrame
# Columns: [year, count_adm1s, min_dekad]
# Index: []
#     year  count_adm1s  min_dekad
# 0   2001            1         26
# 1   2002            4         21
# 2   2004            4         22
# 3   2005            1         21
# 4   2006            3         21
# 5   2007            3         21
# 6   2008            2         21
# 7   2009            2         21
# 8   2010            2         21
# 9   2011            4         21
# 10  2013            1         21
# 11  2014            3         22
# 12  2015            2         21
# 13  2017            2         26
# 14  2019            2         21
# 15  2020            1         21
# 16  2021            3         26
# 17  2024            2         21
#    year  count_adm1s  min_dekad
# 0  2002            3         21
# 1  2004            2         23
# 2  2006            3         21
# 3  2009            2         21
# 4  2010            1         21
# 5  2011            3         21
# 6  2015            2         21
# 7  2019            2         21
# 8  2020            1         21
# 9  2024            1         21
#    year  count_adm1s  min_dekad
# 0  2002            3         21
# 1  2004            2         23
# 2  2006            2         21
# 3  2009            1         21
# 4  2015            1         21
# 5  2019            1         27
# Empty DataFrame
# Columns: [year, count_adm1s, min_dekad]
# Index: []
#     year  count_adm1s  min_dekad
# 0   2001            1         26
# 1   2002            4         21
# 2   2004            4         22
# 3   2005            1         21
# 4   2006            3         21
# 5   2007            3         21
# 6   2008            2         21
# 7   2009            2         21
# 8   2010            2         21
# 9   2011            4         21
# 10  2013            1         21
# 11  2014            3         22
# 12  2015            2         21
# 13  2017            2         26
# 14  2019            2         21
# 15  2020            1         21
# 16  2021            3         26
# 17  2024            2         21
#    year  count_adm1s  min_dekad
# 0  2002            3         21
# 1  2004            2         23
# 2  2006            3         21
# 3  2009            2         21
# 4  2010            1         21
# 5  2011            3         21
# 6  2015            2         21
# 7  2019            2         21
# 8  2020            1         21
# 9  2024            1         21
#    year  count_adm1s  min_dekad
# 0  2002            3         21
# 1  2004            2         23
# 2  2006            2         21
# 3  2009            1         21
# 4  2015            1         21
# 5  2019            1         27
# Empty DataFrame
# Columns: [year, count_adm1s, min_dekad]
# Index: []
#     year  count_adm1s  min_dekad
# 0   2001            1         26
# 1   2002            4         21
# 2   2004            4         22
# 3   2005            1         21
# 4   2006            3         21
# 5   2007            3         21
# 6   2008            2         21
# 7   2009            2         21
# 8   2010            2         21
# 9   2011            4         21
# 10  2013            1         21
# 11  2014            3         22
# 12  2015            2         21
# 13  2017            2         26
# 14  2019            2         21
# 15  2020            1         21
# 16  2021            3         26
# 17  2024            2         21
#    year  count_adm1s  min_dekad
# 0  2002            3         21
# 1  2004            2         23
# 2  2006            3         21
# 3  2009            2         21
# 4  2010            1         21
# 5  2011            3         21
# 6  2015            2         21
# 7  2019            2         21
# 8  2020            1         21
# 9  2024            1         21
#    year  count_adm1s  min_dekad
# 0  2002            3         21
# 1  2004            2         23
# 2  2006            2         21
# 3  2009            1         21
# 4  2015            1         21
# 5  2019            1         27
# Empty DataFrame
# Columns: [year, count_adm1s, min_dekad]
# Index: []
#     year  count_adm1s  min_dekad
# 0   2001            1         26
# 1   2002            4         21
# 2   2004            4         22
# 3   2005            1         21
# 4   2006            3         21
# 5   2007            3         21
# 6   2008            2         21
# 7   2009            2         21
# 8   2010            2         21
# 9   2011            4         21
# 10  2013            1         21
# 11  2014            3         22
# 12  2015            2         21
# 13  2017            2         26
# 14  2019            2         21
# 15  2020            1         21
# 16  2021            3         26
# 17  2024            2         21
#    year  count_adm1s  min_dekad
# 0  2002            3         21
# 1  2004            2         23
# 2  2006            3         21
# 3  2009            2         21
# 4  2010            1         21
# 5  2011            3         21
# 6  2015            2         21
# 7  2019            2         21
# 8  2020            1         21
# 9  2024            1         21
#    year  count_adm1s  min_dekad
# 0  2002            3         21
# 1  2004            2         23
# 2  2006            2         21
# 3  2009            1         21
# 4  2015            1         21
# 5  2019            1         27
# Empty DataFrame
# Columns: [year, count_adm1s, min_dekad]
# Index: []

# %%
df_triggers[
    (df_triggers["crop_range"] == "OR")
    & (df_triggers["minadm1s"] == 4)
    & (df_triggers["al"] == 4)
]
# Out:
# Empty DataFrame
# Columns: [year, min_dekad, crop_range, minadm1s, al]
# Index: []

# %% [markdown]
# ### Calculate return period

# %%
df_rps = (
    df_triggers.groupby(["crop_range", "minadm1s", "al"])
    .agg(count=("year", "size"), min_dekad=("min_dekad", "mean"))
    .reset_index()
)
df_rps["rp"] = (len(all_years) + 1) / df_rps["count"]
df_rps = df_rps.sort_values("rp", ascending=False)
df_rps
# Out:
#    crop_range  minadm1s  al  count  min_dekad         rp
# 21         OR         4   3      1  21.000000  26.000000
# 8         AND         3   3      1  21.000000  26.000000
# 20         OR         4   2      2  21.000000  13.000000
# 18         OR         3   3      2  21.000000  13.000000
# 5         AND         2   3      3  21.666667   8.666667
# 7         AND         3   2      3  21.000000   8.666667
# 9         AND         4   1      3  21.333333   8.666667
# 19         OR         4   1      4  21.000000   6.500000
# 15         OR         2   3      4  21.250000   6.500000
# 17         OR         3   2      5  21.000000   5.200000
# 2         AND         1   3      6  22.333333   4.333333
# 4         AND         2   2      7  21.285714   3.714286
# 6         AND         3   1      7  22.000000   3.714286
# 1         AND         1   2     10  21.200000   2.600000
# 12         OR         1   3     10  22.000000   2.600000
# 14         OR         2   2     10  21.000000   2.600000
# 11         OR         1   2     13  21.615385   2.000000
# 16         OR         3   1     13  21.692308   2.000000
# 3         AND         2   1     14  21.857143   1.857143
# 13         OR         2   1     17  21.647059   1.529412
# 0         AND         1   1     18  21.944444   1.444444
# 10         OR         1   1     20  21.750000   1.300000

# %% [markdown]
# ### Plot RP of options

# %%
lower_rp, upper_rp = 4, 20

# %%
def plot_asap_heatmap(crop_range):
    bounds = [0, lower_rp, upper_rp, 1000]
    tick_bounds = bounds[1:-1]
    cmap = plt.cm.Spectral_r
    norm = mcolors.BoundaryNorm(bounds, cmap.N)
    crop_range_fr = "OU" if crop_range == "OR" else "ET"
    df_plot = df_rps[df_rps["crop_range"] == crop_range].pivot(
        values="rp", columns="minadm1s", index="al"
    )

    fig, ax = plt.subplots(dpi=200)

    sns.heatmap(df_plot, annot=True, cmap=cmap, norm=norm, ax=ax, cbar=False)

    ax.invert_yaxis()
    ax.set_aspect("equal", adjustable="box")

    ax.set_title(
        f"Période de retour d'alertes ASAP\n(agricole {crop_range_fr} pâturage)"
    )
    ax.set_xlabel("Nombre de régions avec alerte")
    ax.set_ylabel("Niveau d'alerte minimum")

# %%
plot_asap_heatmap("OR")

# %%
plot_asap_heatmap("AND")

# %% [markdown]
# ### Plot trigger timing of options

# %%
def plot_asap_heatmap_min_dekad(crop_range):
    crop_range_fr = "OU" if crop_range == "OR" else "ET"
    df_plot = df_rps[df_rps["crop_range"] == crop_range].pivot(
        values="min_dekad", columns="minadm1s", index="al"
    )

    fig, ax = plt.subplots(dpi=200)

    sns.heatmap(
        df_plot, cmap="autumn_r", annot=True, ax=ax, cbar=False, fmt=".1f"
    )

    ax.invert_yaxis()
    ax.set_aspect("equal", adjustable="box")

    ax.set_title(
        f"Première décade de déclenchement ASAP\n(agricole {crop_range_fr} pâturage)"
    )
    ax.set_xlabel("Nombre de régions avec alerte")
    ax.set_ylabel("Niveau d'alerte minimum")

# %%
plot_asap_heatmap_min_dekad("OR")

# %%
plot_asap_heatmap_min_dekad("AND")

# %%
# set naming structure for ASAP triggers
ASAP_COL = (
    "Niveau ≥ {al}<br>N. régions ≥ {minadm1s}<br>" "Ag. {crop_range_fr} Pât."
)

# %%
# set up reverse of naming structure
# in retropsect this could've all been avoided with proper grouping
# but this works for now
def extract_asap_params(formatted_string):
    # Define a regular expression pattern to match the expected format, allowing crop_range_fr to be a string
    pattern = r"Niveau ≥ (?P<al>\d+)<br>N\. régions ≥ (?P<minadm1s>\d+)<br>Ag\. (?P<crop_range_fr>[\w\s]+) Pât\."

    # Search the string for matches
    match = re.search(pattern, formatted_string)

    if match:
        # Extract the matched values
        al = match.group("al")
        minadm1s = match.group("minadm1s")
        crop_range_fr = match.group("crop_range_fr")
        return al, minadm1s, crop_range_fr
    else:
        raise ValueError("The string does not match the expected format")

# %% [markdown]
# ### Check specific years triggered

# %%
df_asap_yearly = pd.DataFrame(data={"year": range(2001, 2025)})
for _, row in df_rps.iterrows():
    crop_range_fr = "OU" if row["crop_range"] == "OR" else "ET"
    col_name = ASAP_COL.format(
        al=row["al"], minadm1s=row["minadm1s"], crop_range_fr=crop_range_fr
    )
    df_triggers_f = df_triggers[
        (df_triggers["crop_range"] == row["crop_range"])
        & (df_triggers["al"] == row["al"])
        & (df_triggers["minadm1s"] == row["minadm1s"])
    ]
    df_asap_yearly[col_name] = df_asap_yearly["year"].apply(
        lambda x: x in df_triggers_f["year"].unique()
    )

# %%
crop_range
# Out:
# 'AND'

# %%
df_triggers[
    (df_triggers["crop_range"] == crop_range)
    & (df_triggers["al"] == row["al"])
    & (df_triggers["minadm1s"] == row["minadm1s"])
]
# Out:
#      year  min_dekad crop_range  minadm1s  al
# 101  2001         26        AND         1   1
# 102  2002         21        AND         1   1
# 103  2004         22        AND         1   1
# 104  2005         21        AND         1   1
# 105  2006         21        AND         1   1
# 106  2007         21        AND         1   1
# 107  2008         21        AND         1   1
# 108  2009         21        AND         1   1
# 109  2010         21        AND         1   1
# 110  2011         21        AND         1   1
# 111  2013         21        AND         1   1
# 112  2014         22        AND         1   1
# 113  2015         21        AND         1   1
# 114  2017         26        AND         1   1
# 115  2019         21        AND         1   1
# 116  2020         21        AND         1   1
# 117  2021         26        AND         1   1
# 118  2024         21        AND         1   1

# %%
def highlight_true(value):
    if isinstance(value, bool) and value is True or value == "Activation":
        return "background-color: crimson; color: white"
    elif (
        isinstance(value, bool)
        and value is False
        or value == "Pas d'activation"
    ):
        return "color: lightgrey"
    else:
        return ""


def display_asap_activations(crop_range):
    dff = df_rps[
        (df_rps["rp"] >= lower_rp)
        & (df_rps["rp"] <= upper_rp)
        & (df_rps["crop_range"] == crop_range)
    ]

    df_disp = pd.DataFrame(data={"year": range(2001, 2025)})
    for _, row in dff.iterrows():
        col_name = f'Niveau ≥ {row["al"]}<br>N. régions ≥ {row["minadm1s"]}'
        df_triggers_f = df_triggers[
            (df_triggers["crop_range"] == crop_range)
            & (df_triggers["al"] == row["al"])
            & (df_triggers["minadm1s"] == row["minadm1s"])
        ]
        df_disp[col_name] = df_disp["year"].apply(
            lambda x: x in df_triggers_f["year"].unique()
        )

    display(
        df_disp.sort_values("year", ascending=False)
        .rename(columns={"year": "Année"})
        .set_index("Année")
        .style.map(highlight_true)
    )

# %%
display_asap_activations("OR")
# Out:
# <style type="text/css">
# #T_32fe8_row0_col0, #T_32fe8_row0_col1, #T_32fe8_row0_col2, #T_32fe8_row0_col3, #T_32fe8_row0_col4, #T_32fe8_row1_col0, #T_32fe8_row1_col1, #T_32fe8_row1_col2, #T_32fe8_row1_col3, #T_32fe8_row1_col4, #T_32fe8_row2_col0, #T_32fe8_row2_col1, #T_32fe8_row2_col2, #T_32fe8_row2_col3, #T_32fe8_row2_col4, #T_32fe8_row3_col0, #T_32fe8_row3_col1, #T_32fe8_row3_col2, #T_32fe8_row3_col3, #T_32fe8_row3_col4, #T_32fe8_row4_col0, #T_32fe8_row4_col1, #T_32fe8_row4_col2, #T_32fe8_row4_col3, #T_32fe8_row4_col4, #T_32fe8_row5_col0, #T_32fe8_row5_col1, #T_32fe8_row5_col2, #T_32fe8_row5_col3, #T_32fe8_row6_col0, #T_32fe8_row6_col1, #T_32fe8_row6_col2, #T_32fe8_row6_col3, #T_32fe8_row6_col4, #T_32fe8_row7_col0, #T_32fe8_row7_col1, #T_32fe8_row7_col2, #T_32fe8_row7_col3, #T_32fe8_row7_col4, #T_32fe8_row8_col0, #T_32fe8_row8_col1, #T_32fe8_row8_col2, #T_32fe8_row8_col3, #T_32fe8_row8_col4, #T_32fe8_row9_col0, #T_32fe8_row9_col1, #T_32fe8_row9_col2, #T_32fe8_row9_col3, #T_32fe8_row10_col0, #T_32fe8_row10_col1, #T_32fe8_row10_col2, #T_32fe8_row10_col3, #T_32fe8_row10_col4, #T_32fe8_row11_col0, #T_32fe8_row11_col1, #T_32fe8_row11_col2, #T_32fe8_row11_col3, #T_32fe8_row11_col4, #T_32fe8_row12_col0, #T_32fe8_row12_col1, #T_32fe8_row12_col2, #T_32fe8_row12_col3, #T_32fe8_row12_col4, #T_32fe8_row13_col0, #T_32fe8_row13_col1, #T_32fe8_row13_col3, #T_32fe8_row14_col0, #T_32fe8_row14_col1, #T_32fe8_row14_col2, #T_32fe8_row14_col3, #T_32fe8_row14_col4, #T_32fe8_row15_col0, #T_32fe8_row15_col1, #T_32fe8_row15_col2, #T_32fe8_row15_col4, #T_32fe8_row16_col0, #T_32fe8_row16_col1, #T_32fe8_row16_col2, #T_32fe8_row16_col3, #T_32fe8_row16_col4, #T_32fe8_row17_col0, #T_32fe8_row17_col1, #T_32fe8_row17_col2, #T_32fe8_row17_col3, #T_32fe8_row17_col4, #T_32fe8_row19_col0, #T_32fe8_row19_col1, #T_32fe8_row19_col2, #T_32fe8_row19_col3, #T_32fe8_row19_col4, #T_32fe8_row20_col0, #T_32fe8_row20_col1, #T_32fe8_row20_col4, #T_32fe8_row21_col0, #T_32fe8_row21_col1, #T_32fe8_row21_col2, #T_32fe8_row21_col3, #T_32fe8_row21_col4, #T_32fe8_row23_col0, #T_32fe8_row23_col1, #T_32fe8_row23_col2, #T_32fe8_row23_col3, #T_32fe8_row23_col4 {
#   color: lightgrey;
# }
# #T_32fe8_row5_col4, #T_32fe8_row9_col4, #T_32fe8_row13_col2, #T_32fe8_row13_col4, #T_32fe8_row15_col3, #T_32fe8_row18_col0, #T_32fe8_row18_col1, #T_32fe8_row18_col2, #T_32fe8_row18_col3, #T_32fe8_row18_col4, #T_32fe8_row20_col2, #T_32fe8_row20_col3, #T_32fe8_row22_col0, #T_32fe8_row22_col1, #T_32fe8_row22_col2, #T_32fe8_row22_col3, #T_32fe8_row22_col4 {
#   background-color: crimson;
#   color: white;
# }
# </style>
# <table id="T_32fe8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_32fe8_level0_col0" class="col_heading level0 col0" >Niveau ≥ 2<br>N. régions ≥ 4</th>
#       <th id="T_32fe8_level0_col1" class="col_heading level0 col1" >Niveau ≥ 3<br>N. régions ≥ 3</th>
#       <th id="T_32fe8_level0_col2" class="col_heading level0 col2" >Niveau ≥ 1<br>N. régions ≥ 4</th>
#       <th id="T_32fe8_level0_col3" class="col_heading level0 col3" >Niveau ≥ 3<br>N. régions ≥ 2</th>
#       <th id="T_32fe8_level0_col4" class="col_heading level0 col4" >Niveau ≥ 2<br>N. régions ≥ 3</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Année</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_32fe8_level0_row0" class="row_heading level0 row0" >2024</th>
#       <td id="T_32fe8_row0_col0" class="data row0 col0" >False</td>
#       <td id="T_32fe8_row0_col1" class="data row0 col1" >False</td>
#       <td id="T_32fe8_row0_col2" class="data row0 col2" >False</td>
#       <td id="T_32fe8_row0_col3" class="data row0 col3" >False</td>
#       <td id="T_32fe8_row0_col4" class="data row0 col4" >False</td>
#     </tr>
#     <tr>
#       <th id="T_32fe8_level0_row1" class="row_heading level0 row1" >2023</th>
#       <td id="T_32fe8_row1_col0" class="data row1 col0" >False</td>
#       <td id="T_32fe8_row1_col1" class="data row1 col1" >False</td>
#       <td id="T_32fe8_row1_col2" class="data row1 col2" >False</td>
#       <td id="T_32fe8_row1_col3" class="data row1 col3" >False</td>
#       <td id="T_32fe8_row1_col4" class="data row1 col4" >False</td>
#     </tr>
#     <tr>
#       <th id="T_32fe8_level0_row2" class="row_heading level0 row2" >2022</th>
#       <td id="T_32fe8_row2_col0" class="data row2 col0" >False</td>
#       <td id="T_32fe8_row2_col1" class="data row2 col1" >False</td>
#       <td id="T_32fe8_row2_col2" class="data row2 col2" >False</td>
#       <td id="T_32fe8_row2_col3" class="data row2 col3" >False</td>
#       <td id="T_32fe8_row2_col4" class="data row2 col4" >False</td>
#     </tr>
#     <tr>
#       <th id="T_32fe8_level0_row3" class="row_heading level0 row3" >2021</th>
#       <td id="T_32fe8_row3_col0" class="data row3 col0" >False</td>
#       <td id="T_32fe8_row3_col1" class="data row3 col1" >False</td>
#       <td id="T_32fe8_row3_col2" class="data row3 col2" >False</td>
#       <td id="T_32fe8_row3_col3" class="data row3 col3" >False</td>
#       <td id="T_32fe8_row3_col4" class="data row3 col4" >False</td>
#     </tr>
#     <tr>
#       <th id="T_32fe8_level0_row4" class="row_heading level0 row4" >2020</th>
#       <td id="T_32fe8_row4_col0" class="data row4 col0" >False</td>
#       <td id="T_32fe8_row4_col1" class="data row4 col1" >False</td>
#       <td id="T_32fe8_row4_col2" class="data row4 col2" >False</td>
#       <td id="T_32fe8_row4_col3" class="data row4 col3" >False</td>
#       <td id="T_32fe8_row4_col4" class="data row4 col4" >False</td>
#     </tr>
#     <tr>
#       <th id="T_32fe8_level0_row5" class="row_heading level0 row5" >2019</th>
#       <td id="T_32fe8_row5_col0" class="data row5 col0" >False</td>
#       <td id="T_32fe8_row5_col1" class="data row5 col1" >False</td>
#       <td id="T_32fe8_row5_col2" class="data row5 col2" >False</td>
#       <td id="T_32fe8_row5_col3" class="data row5 col3" >False</td>
#       <td id="T_32fe8_row5_col4" class="data row5 col4" >True</td>
#     </tr>
#     <tr>
#       <th id="T_32fe8_level0_row6" class="row_heading level0 row6" >2018</th>
#       <td id="T_32fe8_row6_col0" class="data row6 col0" >False</td>
#       <td id="T_32fe8_row6_col1" class="data row6 col1" >False</td>
#       <td id="T_32fe8_row6_col2" class="data row6 col2" >False</td>
#       <td id="T_32fe8_row6_col3" class="data row6 col3" >False</td>
#       <td id="T_32fe8_row6_col4" class="data row6 col4" >False</td>
#     </tr>
#     <tr>
#       <th id="T_32fe8_level0_row7" class="row_heading level0 row7" >2017</th>
#       <td id="T_32fe8_row7_col0" class="data row7 col0" >False</td>
#       <td id="T_32fe8_row7_col1" class="data row7 col1" >False</td>
#       <td id="T_32fe8_row7_col2" class="data row7 col2" >False</td>
#       <td id="T_32fe8_row7_col3" class="data row7 col3" >False</td>
#       <td id="T_32fe8_row7_col4" class="data row7 col4" >False</td>
#     </tr>
#     <tr>
#       <th id="T_32fe8_level0_row8" class="row_heading level0 row8" >2016</th>
#       <td id="T_32fe8_row8_col0" class="data row8 col0" >False</td>
#       <td id="T_32fe8_row8_col1" class="data row8 col1" >False</td>
#       <td id="T_32fe8_row8_col2" class="data row8 col2" >False</td>
#       <td id="T_32fe8_row8_col3" class="data row8 col3" >False</td>
#       <td id="T_32fe8_row8_col4" class="data row8 col4" >False</td>
#     </tr>
#     <tr>
#       <th id="T_32fe8_level0_row9" class="row_heading level0 row9" >2015</th>
#       <td id="T_32fe8_row9_col0" class="data row9 col0" >False</td>
#       <td id="T_32fe8_row9_col1" class="data row9 col1" >False</td>
#       <td id="T_32fe8_row9_col2" class="data row9 col2" >False</td>
#       <td id="T_32fe8_row9_col3" class="data row9 col3" >False</td>
#       <td id="T_32fe8_row9_col4" class="data row9 col4" >True</td>
#     </tr>
#     <tr>
#       <th id="T_32fe8_level0_row10" class="row_heading level0 row10" >2014</th>
#       <td id="T_32fe8_row10_col0" class="data row10 col0" >False</t

# %%
display_asap_activations("AND")
# Out:
# <style type="text/css">
# #T_33173_row0_col0, #T_33173_row0_col1, #T_33173_row0_col2, #T_33173_row0_col3, #T_33173_row1_col0, #T_33173_row1_col1, #T_33173_row1_col2, #T_33173_row1_col3, #T_33173_row2_col0, #T_33173_row2_col1, #T_33173_row2_col2, #T_33173_row2_col3, #T_33173_row3_col0, #T_33173_row3_col1, #T_33173_row3_col2, #T_33173_row3_col3, #T_33173_row4_col0, #T_33173_row4_col1, #T_33173_row4_col2, #T_33173_row4_col3, #T_33173_row5_col0, #T_33173_row5_col1, #T_33173_row5_col2, #T_33173_row6_col0, #T_33173_row6_col1, #T_33173_row6_col2, #T_33173_row6_col3, #T_33173_row7_col0, #T_33173_row7_col1, #T_33173_row7_col2, #T_33173_row7_col3, #T_33173_row8_col0, #T_33173_row8_col1, #T_33173_row8_col2, #T_33173_row8_col3, #T_33173_row9_col0, #T_33173_row9_col1, #T_33173_row9_col2, #T_33173_row10_col0, #T_33173_row10_col1, #T_33173_row10_col2, #T_33173_row10_col3, #T_33173_row11_col0, #T_33173_row11_col1, #T_33173_row11_col2, #T_33173_row11_col3, #T_33173_row12_col0, #T_33173_row12_col1, #T_33173_row12_col2, #T_33173_row12_col3, #T_33173_row13_col0, #T_33173_row13_col3, #T_33173_row14_col0, #T_33173_row14_col1, #T_33173_row14_col2, #T_33173_row14_col3, #T_33173_row15_col0, #T_33173_row15_col1, #T_33173_row15_col2, #T_33173_row16_col0, #T_33173_row16_col1, #T_33173_row16_col2, #T_33173_row16_col3, #T_33173_row17_col0, #T_33173_row17_col1, #T_33173_row17_col2, #T_33173_row17_col3, #T_33173_row18_col2, #T_33173_row19_col0, #T_33173_row19_col1, #T_33173_row19_col2, #T_33173_row19_col3, #T_33173_row20_col1, #T_33173_row21_col0, #T_33173_row21_col1, #T_33173_row21_col2, #T_33173_row21_col3, #T_33173_row23_col0, #T_33173_row23_col1, #T_33173_row23_col2, #T_33173_row23_col3 {
#   color: lightgrey;
# }
# #T_33173_row5_col3, #T_33173_row9_col3, #T_33173_row13_col1, #T_33173_row13_col2, #T_33173_row15_col3, #T_33173_row18_col0, #T_33173_row18_col1, #T_33173_row18_col3, #T_33173_row20_col0, #T_33173_row20_col2, #T_33173_row20_col3, #T_33173_row22_col0, #T_33173_row22_col1, #T_33173_row22_col2, #T_33173_row22_col3 {
#   background-color: crimson;
#   color: white;
# }
# </style>
# <table id="T_33173">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33173_level0_col0" class="col_heading level0 col0" >Niveau ≥ 3<br>N. régions ≥ 2</th>
#       <th id="T_33173_level0_col1" class="col_heading level0 col1" >Niveau ≥ 2<br>N. régions ≥ 3</th>
#       <th id="T_33173_level0_col2" class="col_heading level0 col2" >Niveau ≥ 1<br>N. régions ≥ 4</th>
#       <th id="T_33173_level0_col3" class="col_heading level0 col3" >Niveau ≥ 3<br>N. régions ≥ 1</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Année</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33173_level0_row0" class="row_heading level0 row0" >2024</th>
#       <td id="T_33173_row0_col0" class="data row0 col0" >False</td>
#       <td id="T_33173_row0_col1" class="data row0 col1" >False</td>
#       <td id="T_33173_row0_col2" class="data row0 col2" >False</td>
#       <td id="T_33173_row0_col3" class="data row0 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_33173_level0_row1" class="row_heading level0 row1" >2023</th>
#       <td id="T_33173_row1_col0" class="data row1 col0" >False</td>
#       <td id="T_33173_row1_col1" class="data row1 col1" >False</td>
#       <td id="T_33173_row1_col2" class="data row1 col2" >False</td>
#       <td id="T_33173_row1_col3" class="data row1 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_33173_level0_row2" class="row_heading level0 row2" >2022</th>
#       <td id="T_33173_row2_col0" class="data row2 col0" >False</td>
#       <td id="T_33173_row2_col1" class="data row2 col1" >False</td>
#       <td id="T_33173_row2_col2" class="data row2 col2" >False</td>
#       <td id="T_33173_row2_col3" class="data row2 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_33173_level0_row3" class="row_heading level0 row3" >2021</th>
#       <td id="T_33173_row3_col0" class="data row3 col0" >False</td>
#       <td id="T_33173_row3_col1" class="data row3 col1" >False</td>
#       <td id="T_33173_row3_col2" class="data row3 col2" >False</td>
#       <td id="T_33173_row3_col3" class="data row3 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_33173_level0_row4" class="row_heading level0 row4" >2020</th>
#       <td id="T_33173_row4_col0" class="data row4 col0" >False</td>
#       <td id="T_33173_row4_col1" class="data row4 col1" >False</td>
#       <td id="T_33173_row4_col2" class="data row4 col2" >False</td>
#       <td id="T_33173_row4_col3" class="data row4 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_33173_level0_row5" class="row_heading level0 row5" >2019</th>
#       <td id="T_33173_row5_col0" class="data row5 col0" >False</td>
#       <td id="T_33173_row5_col1" class="data row5 col1" >False</td>
#       <td id="T_33173_row5_col2" class="data row5 col2" >False</td>
#       <td id="T_33173_row5_col3" class="data row5 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_33173_level0_row6" class="row_heading level0 row6" >2018</th>
#       <td id="T_33173_row6_col0" class="data row6 col0" >False</td>
#       <td id="T_33173_row6_col1" class="data row6 col1" >False</td>
#       <td id="T_33173_row6_col2" class="data row6 col2" >False</td>
#       <td id="T_33173_row6_col3" class="data row6 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_33173_level0_row7" class="row_heading level0 row7" >2017</th>
#       <td id="T_33173_row7_col0" class="data row7 col0" >False</td>
#       <td id="T_33173_row7_col1" class="data row7 col1" >False</td>
#       <td id="T_33173_row7_col2" class="data row7 col2" >False</td>
#       <td id="T_33173_row7_col3" class="data row7 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_33173_level0_row8" class="row_heading level0 row8" >2016</th>
#       <td id="T_33173_row8_col0" class="data row8 col0" >False</td>
#       <td id="T_33173_row8_col1" class="data row8 col1" >False</td>
#       <td id="T_33173_row8_col2" class="data row8 col2" >False</td>
#       <td id="T_33173_row8_col3" class="data row8 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_33173_level0_row9" class="row_heading level0 row9" >2015</th>
#       <td id="T_33173_row9_col0" class="data row9 col0" >False</td>
#       <td id="T_33173_row9_col1" class="data row9 col1" >False</td>
#       <td id="T_33173_row9_col2" class="data row9 col2" >False</td>
#       <td id="T_33173_row9_col3" class="data row9 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_33173_level0_row10" class="row_heading level0 row10" >2014</th>
#       <td id="T_33173_row10_col0" class="data row10 col0" >False</td>
#       <td id="T_33173_row10_col1" class="data row10 col1" >False</td>
#       <td id="T_33173_row10_col2" class="data row10 col2" >False</td>
#       <td id="T_33173_row10_col3" class="data row10 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_33173_level0_row11" class="row_heading level0 row11" >2013</th>
#       <td id="T_33173_row11_col0" class="data row11 col0" >False</td>
#       <td id="T_33173_row11_col1" class="data row11 col1" >False</td>
#       <td id="T_33173_row11_col2" class="data row11 col2" >False</td>
#       <td id="T_33173_row11_col3" class="data row11 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_33173_level0_row12" class="row_heading level0 row12" >2012</th>
#       <td id="T_33173_row12_col0" class="data row12 col0" >False</td>
#       <td id="T_33173_row12_col1" class="data row12 col1" >False</td>
#       <td id="T_33173_row12_col2" class="data row12 col2" >False</td>
#       <td id="T_33173_row12_col3" class="data row12 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_33173_level0_row13" class="row_heading level0 row13" >2011</th>
#       <td id="T_33173_row13_col0" class="data row13 col0" >False</td>
#       <td id="T_33173_row13_col1" class="data row13 col1" >True</td>
#       <td id="T_33173_row13_col2" class="data row13 col2" >True</td>
#       <td id="T_33173_row13_col3" class=

# %% [markdown]
# ## Combined RP
#
# ### Load SEAS5

# %%
df_seas5 = seas5.load_seas5_stats(variable="rank")

# %%
df_seas5
# Out:
#     year  issued_month         q
# 0   1981             3  0.363636
# 1   1981             7  0.181818
# 2   1982             3  0.363636
# 3   1982             7  0.068182
# 4   1983             3  0.022727
# ..   ...           ...       ...
# 83  2022             7  0.750000
# 84  2023             3  0.409091
# 85  2023             7  0.840909
# 86  2024             3  0.545455
# 87  2024             7  0.295455
#
# [88 rows x 3 columns]

# %%
df_seas5_yearly = df_seas5.pivot(
    index="year", columns="issued_month", values="q"
).reset_index()
df_seas5_yearly = df_seas5_yearly.rename(
    columns={x: f"issued_{x}" for x in [3, 7]}
)

# %% [markdown]
# ### Merge with ASAP

# %%
df_both_yearly = df_seas5_yearly.merge(df_asap_yearly).sort_values(
    "year", ascending=False
)

# %%
df_both_yearly[ASAP_COL.format(al=4, crop_range_fr="OU", minadm1s=4)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/pa-aa-bfa-drought/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Niveau ≥ 4<br>N. régions ≥ 4<br>Ag. OU Pât.'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 df_both_yearly[ASAP_COL.format(al=4, crop_range_fr="OU", minadm1s=4)]
#
# File ~/.pyenv/versions/pa-aa-bfa-drought/lib/python3.11/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~/.pyenv/versions/pa-aa-bfa-drought/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Niveau ≥ 4<br>N. régions ≥ 4<br>Ag. OU Pât.'

# %% [markdown]
# Quickly check the individual RP of SEAS5

# %%
rp_based = False

rp_seas5 = 8
fixed_thresh = -0.75


for mo in [3, 7]:
    if rp_based:
        df_both_yearly[f"issued_{mo}_bool"] = df_both_yearly[
            f"issued_{mo}"
        ] < df_both_yearly[f"issued_{mo}"].quantile(1 / rp_seas5)
    else:
        df_both_yearly[f"issued_{mo}_bool"] = (
            df_both_yearly[f"issued_{mo}"] < fixed_thresh
        )
        print(f"issued month {mo}:")
        print((len(all_years) + 1) / df_both_yearly[f"issued_{mo}_bool"].sum())
        print()
# Out:
# issued month 3:
# inf
#
# issued month 7:
# inf
# /var/folders/66/764yc5p92nvdc_nm3xmy5rn40000gn/T/ipykernel_73264/3955251585.py:17: RuntimeWarning: divide by zero encountered in scalar divide
#   print((len(all_years) + 1) / df_both_yearly[f"issued_{mo}_bool"].sum())
# /var/folders/66/764yc5p92nvdc_nm3xmy5rn40000gn/T/ipykernel_73264/3955251585.py:17: RuntimeWarning: divide by zero encountered in scalar divide
#   print((len(all_years) + 1) / df_both_yearly[f"issued_{mo}_bool"].sum())

# %%
df_both_yearly[["year"] + [f"issued_{mo}_bool" for mo in [3, 7]]]
# Out:
#     year  issued_3_bool  issued_7_bool
# 23  2024          False          False
# 22  2023          False          False
# 21  2022          False          False
# 20  2021          False          False
# 19  2020          False          False
# 18  2019          False          False
# 17  2018          False          False
# 16  2017          False          False
# 15  2016          False          False
# 14  2015          False          False
# 13  2014          False          False
# 12  2013          False          False
# 11  2012          False          False
# 10  2011          False          False
# 9   2010          False          False
# 8   2009          False          False
# 7   2008          False          False
# 6   2007          False          False
# 5   2006          False          False
# 4   2005          False          False
# 3   2004          False          False
# 2   2003          False          False
# 1   2002          False          False
# 0   2001          False          False

# %% [markdown]
# ### Determine combined RPs

# %%
asap_col = ASAP_COL.format(al=2, minadm1s=3, crop_range_fr="ET")

df_both_yearly.set_index("year")[
    ["issued_3_bool", "issued_7_bool", asap_col]
].style.map(highlight_true)
# Out:
# <style type="text/css">
# #T_5a0fc_row0_col0, #T_5a0fc_row0_col1, #T_5a0fc_row0_col2, #T_5a0fc_row1_col0, #T_5a0fc_row1_col1, #T_5a0fc_row1_col2, #T_5a0fc_row2_col0, #T_5a0fc_row2_col1, #T_5a0fc_row2_col2, #T_5a0fc_row3_col0, #T_5a0fc_row3_col1, #T_5a0fc_row3_col2, #T_5a0fc_row4_col0, #T_5a0fc_row4_col1, #T_5a0fc_row4_col2, #T_5a0fc_row5_col0, #T_5a0fc_row5_col1, #T_5a0fc_row5_col2, #T_5a0fc_row6_col0, #T_5a0fc_row6_col1, #T_5a0fc_row6_col2, #T_5a0fc_row7_col0, #T_5a0fc_row7_col1, #T_5a0fc_row7_col2, #T_5a0fc_row8_col0, #T_5a0fc_row8_col1, #T_5a0fc_row8_col2, #T_5a0fc_row9_col0, #T_5a0fc_row9_col1, #T_5a0fc_row9_col2, #T_5a0fc_row10_col0, #T_5a0fc_row10_col1, #T_5a0fc_row10_col2, #T_5a0fc_row11_col0, #T_5a0fc_row11_col1, #T_5a0fc_row11_col2, #T_5a0fc_row12_col0, #T_5a0fc_row12_col1, #T_5a0fc_row12_col2, #T_5a0fc_row13_col0, #T_5a0fc_row13_col1, #T_5a0fc_row14_col0, #T_5a0fc_row14_col1, #T_5a0fc_row14_col2, #T_5a0fc_row15_col0, #T_5a0fc_row15_col1, #T_5a0fc_row15_col2, #T_5a0fc_row16_col0, #T_5a0fc_row16_col1, #T_5a0fc_row16_col2, #T_5a0fc_row17_col0, #T_5a0fc_row17_col1, #T_5a0fc_row17_col2, #T_5a0fc_row18_col0, #T_5a0fc_row18_col1, #T_5a0fc_row19_col0, #T_5a0fc_row19_col1, #T_5a0fc_row19_col2, #T_5a0fc_row20_col0, #T_5a0fc_row20_col1, #T_5a0fc_row20_col2, #T_5a0fc_row21_col0, #T_5a0fc_row21_col1, #T_5a0fc_row21_col2, #T_5a0fc_row22_col0, #T_5a0fc_row22_col1, #T_5a0fc_row23_col0, #T_5a0fc_row23_col1, #T_5a0fc_row23_col2 {
#   color: lightgrey;
# }
# #T_5a0fc_row13_col2, #T_5a0fc_row18_col2, #T_5a0fc_row22_col2 {
#   background-color: crimson;
#   color: white;
# }
# </style>
# <table id="T_5a0fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a0fc_level0_col0" class="col_heading level0 col0" >issued_3_bool</th>
#       <th id="T_5a0fc_level0_col1" class="col_heading level0 col1" >issued_7_bool</th>
#       <th id="T_5a0fc_level0_col2" class="col_heading level0 col2" >Niveau ≥ 2<br>N. régions ≥ 3<br>Ag. ET Pât.</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >year</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a0fc_level0_row0" class="row_heading level0 row0" >2024</th>
#       <td id="T_5a0fc_row0_col0" class="data row0 col0" >False</td>
#       <td id="T_5a0fc_row0_col1" class="data row0 col1" >False</td>
#       <td id="T_5a0fc_row0_col2" class="data row0 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a0fc_level0_row1" class="row_heading level0 row1" >2023</th>
#       <td id="T_5a0fc_row1_col0" class="data row1 col0" >False</td>
#       <td id="T_5a0fc_row1_col1" class="data row1 col1" >False</td>
#       <td id="T_5a0fc_row1_col2" class="data row1 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a0fc_level0_row2" class="row_heading level0 row2" >2022</th>
#       <td id="T_5a0fc_row2_col0" class="data row2 col0" >False</td>
#       <td id="T_5a0fc_row2_col1" class="data row2 col1" >False</td>
#       <td id="T_5a0fc_row2_col2" class="data row2 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a0fc_level0_row3" class="row_heading level0 row3" >2021</th>
#       <td id="T_5a0fc_row3_col0" class="data row3 col0" >False</td>
#       <td id="T_5a0fc_row3_col1" class="data row3 col1" >False</td>
#       <td id="T_5a0fc_row3_col2" class="data row3 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a0fc_level0_row4" class="row_heading level0 row4" >2020</th>
#       <td id="T_5a0fc_row4_col0" class="data row4 col0" >False</td>
#       <td id="T_5a0fc_row4_col1" class="data row4 col1" >False</td>
#       <td id="T_5a0fc_row4_col2" class="data row4 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a0fc_level0_row5" class="row_heading level0 row5" >2019</th>
#       <td id="T_5a0fc_row5_col0" class="data row5 col0" >False</td>
#       <td id="T_5a0fc_row5_col1" class="data row5 col1" >False</td>
#       <td id="T_5a0fc_row5_col2" class="data row5 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a0fc_level0_row6" class="row_heading level0 row6" >2018</th>
#       <td id="T_5a0fc_row6_col0" class="data row6 col0" >False</td>
#       <td id="T_5a0fc_row6_col1" class="data row6 col1" >False</td>
#       <td id="T_5a0fc_row6_col2" class="data row6 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a0fc_level0_row7" class="row_heading level0 row7" >2017</th>
#       <td id="T_5a0fc_row7_col0" class="data row7 col0" >False</td>
#       <td id="T_5a0fc_row7_col1" class="data row7 col1" >False</td>
#       <td id="T_5a0fc_row7_col2" class="data row7 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a0fc_level0_row8" class="row_heading level0 row8" >2016</th>
#       <td id="T_5a0fc_row8_col0" class="data row8 col0" >False</td>
#       <td id="T_5a0fc_row8_col1" class="data row8 col1" >False</td>
#       <td id="T_5a0fc_row8_col2" class="data row8 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a0fc_level0_row9" class="row_heading level0 row9" >2015</th>
#       <td id="T_5a0fc_row9_col0" class="data row9 col0" >False</td>
#       <td id="T_5a0fc_row9_col1" class="data row9 col1" >False</td>
#       <td id="T_5a0fc_row9_col2" class="data row9 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a0fc_level0_row10" class="row_heading level0 row10" >2014</th>
#       <td id="T_5a0fc_row10_col0" class="data row10 col0" >False</td>
#       <td id="T_5a0fc_row10_col1" class="data row10 col1" >False</td>
#       <td id="T_5a0fc_row10_col2" class="data row10 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a0fc_level0_row11" class="row_heading level0 row11" >2013</th>
#       <td id="T_5a0fc_row11_col0" class="data row11 col0" >False</td>
#       <td id="T_5a0fc_row11_col1" class="data row11 col1" >False</td>
#       <td id="T_5a0fc_row11_col2" class="data row11 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a0fc_level0_row12" class="row_heading level0 row12" >2012</th>
#       <td id="T_5a0fc_row12_col0" class="data row12 col0" >False</td>
#       <td id="T_5a0fc_row12_col1" class="data row12 col1" >False</td>
#       <td id="T_5a0fc_row12_col2" class="data row12 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a0fc_level0_row13" class="row_heading level0 row13" >2011</th>
#       <td id="T_5a0fc_row13_col0" class="data row13 col0" >False</td>
#       <td id="T_5a0fc_row13_col1" class="data row13 col1" >False</td>
#       <td id="T_5a0fc_row13_col2" class="data row13 col2" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5a0fc_level0_row14" class="row_heading level0 row14" >2010</th>
#       <td id="T_5a0fc_row14_col0" class="data row14 col0" >False</td>
#       <td id="T_5a0fc_row14_col1" class="data row14 col1" >False</td>
#       <td id="T_5a0fc_row14_col2" class="data row14 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a0fc_level0_row15" class="row_heading level0 row15" >2009</th>
#       <td id="T_5a0fc_row15_col0" class="data row15 col0" >False</td>
#       <td id="T_5a0fc_row15_col1" class="data row15 col1" >False</td>
#       <td id="T_5a0fc_row15_col2" class="data row15 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a0fc_level0_row16" class="row_heading level0 row16" >2008</th>
#       <td id="T_5a0fc_row16_col0" class="data row16 col0" >False</td>
#       <td id="T_5a0fc_row16_col1" class="data row16 col1" >False</td>
#       <td id="T_5a0fc_row16_col2" class="data row16 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a0fc_level0_row17" class="row_heading level0 row17" >2007</th>
#       <td id="T_5a0fc_row17_col0" class="data row17 col0" >False</td>
#       <td id="T_5a0fc_row17_col1" class="data row17 col1" >False</td>
#       <td id="T_5a0fc_row17_col2" class="data row17 col2" >False</td>
#     </tr>
#     <tr>
#       <th id="T_5a0fc_level0_row18" class="row_heading level0 row18" >2006</th>
#       <td id="T_5a0fc_row18_col0" class="data row18 col0" >False</td>
#       <td id="T_5a0fc_row18_col1" class="data row18 col1" >False</td>
#       <td id="T_5a0fc_row18_col2" class="data row18 col2" >True</td>
#     </tr>
#     <tr>
#       <th id="T_5a

# %%
for mo in [3, 7]:
    df_both_yearly = rp_calc.calculate_one_group_rp(
        df_both_yearly, col_name=f"issued_{mo}"
    )

# %%
dicts = []

df_plot = df_both_yearly.copy()

asap_cols = [x for x in df_both_yearly.columns if "Niveau" in x]

for rank in range(len(df_plot)):
    df_plot["mar_trig"] = df_plot["issued_3_rank"] <= rank + 1
    df_plot["jul_trig"] = df_plot["issued_7_rank"] <= rank + 1
    rp_seas5_ind = (len(df_plot) + 1) / df_plot["mar_trig"].sum()
    df_plot["seas5_trig"] = df_plot[["mar_trig", "jul_trig"]].any(axis=1)
    rp_seas5_com = (len(df_plot) + 1) / df_plot["seas5_trig"].sum()
    for asap_col in asap_cols:
        rp_asap = (len(df_plot) + 1) / df_plot[asap_col].sum()
        df_plot[f"{asap_col}_any"] = df_plot[[asap_col, "seas5_trig"]].any(
            axis=1
        )
        rp_com = (len(df_plot) + 1) / df_plot[f"{asap_col}_any"].sum()
        if rp_com <= 5 and rp_com >= 3:
            dicts.append(
                {
                    "rp_com": rp_com,
                    "rp_asap": rp_asap,
                    "rp_seas5_com": rp_seas5_com,
                    "rp_seas5_ind": rp_seas5_ind,
                    "asap_col": asap_col,
                }
            )

# %%
df_asap_v_seas5_rp = pd.DataFrame(dicts)

# %%
df_asap_v_seas5_rp
# Out:
#       rp_com    rp_asap  rp_seas5_com  rp_seas5_ind  \
# 0   5.000000   8.333333     12.500000     25.000000
# 1   5.000000   8.333333     12.500000     25.000000
# 2   5.000000   8.333333     12.500000     25.000000
# 3   5.000000   8.333333     12.500000     25.000000
# 4   4.166667   6.250000     12.500000     25.000000
# 5   4.166667   5.000000     12.500000     25.000000
# 6   4.166667   5.000000     12.500000     25.000000
# 7   4.166667   5.000000     12.500000     25.000000
# 8   3.571429   4.166667     12.500000     25.000000
# 9   3.571429   4.166667     12.500000     25.000000
# 10  4.166667   4.166667     12.500000     25.000000
# 11  3.571429   3.571429     12.500000     25.000000
# 12  3.571429   3.571429     12.500000     25.000000
# 13  3.571429   3.571429     12.500000     25.000000
# 14  5.000000  25.000000      6.250000     12.500000
# 15  4.166667  12.500000      6.250000     12.500000
# 16  4.166667  12.500000      6.250000     12.500000
# 17  4.166667  12.500000      6.250000     12.500000
# 18  3.571429   8.333333      6.250000     12.500000
# 19  3.571429   8.333333      6.250000     12.500000
# 20  3.571429   8.333333      6.250000     12.500000
# 21  3.571429   8.333333      6.250000     12.500000
# 22  3.125000   6.250000      6.250000     12.500000
# 23  3.125000   5.000000      6.250000     12.500000
# 24  3.125000   5.000000      6.250000     12.500000
# 25  3.125000   5.000000      6.250000     12.500000
# 26  3.125000   4.166667      6.250000     12.500000
# 27  5.000000  25.000000      6.250000      8.333333
# 28  4.166667  12.500000      6.250000      8.333333
# 29  4.166667  12.500000      6.250000      8.333333
# 30  4.166667  12.500000      6.250000      8.333333
# 31  3.571429   8.333333      6.250000      8.333333
# 32  3.571429   8.333333      6.250000      8.333333
# 33  3.571429   8.333333      6.250000      8.333333
# 34  3.571429   8.333333      6.250000      8.333333
# 35  3.125000   6.250000      6.250000      8.333333
# 36  3.125000   5.000000      6.250000      8.333333
# 37  3.125000   5.000000      6.250000      8.333333
# 38  3.125000   5.000000      6.250000      8.333333
# 39  3.125000   4.166667      6.250000      8.333333
# 40  3.125000  25.000000      3.571429      6.250000
#
#                                        asap_col
# 0   Niveau ≥ 4<br>N. régions ≥ 3<br>Ag. OU Pât.
# 1   Niveau ≥ 2<br>N. régions ≥ 3<br>Ag. ET Pât.
# 2   Niveau ≥ 3<br>N. régions ≥ 3<br>Ag. ET Pât.
# 3   Niveau ≥ 3<br>N. régions ≥ 3<br>Ag. OU Pât.
# 4   Niveau ≥ 1<br>N. régions ≥ 4<br>Ag. ET Pât.
# 5   Niveau ≥ 2<br>N. régions ≥ 3<br>Ag. OU Pât.
# 6   Niveau ≥ 3<br>N. régions ≥ 2<br>Ag. ET Pât.
# 7   Niveau ≥ 4<br>N. régions ≥ 2<br>Ag. ET Pât.
# 8   Niveau ≥ 3<br>N. régions ≥ 2<br>Ag. OU Pât.
# 9   Niveau ≥ 4<br>N. régions ≥ 2<br>Ag. OU Pât.
# 10  Niveau ≥ 4<br>N. régions ≥ 1<br>Ag. ET Pât.
# 11  Niveau ≥ 4<br>N. régions ≥ 1<br>Ag. OU Pât.
# 12  Niveau ≥ 2<br>N. régions ≥ 2<br>Ag. ET Pât.
# 13  Niveau ≥ 3<br>N. régions ≥ 1<br>Ag. ET Pât.
# 14  Niveau ≥ 4<br>N. régions ≥ 4<br>Ag. OU Pât.
# 15  Niveau ≥ 3<br>N. régions ≥ 4<br>Ag. OU Pât.
# 16  Niveau ≥ 2<br>N. régions ≥ 4<br>Ag. OU Pât.
# 17  Niveau ≥ 4<br>N. régions ≥ 3<br>Ag. ET Pât.
# 18  Niveau ≥ 4<br>N. régions ≥ 3<br>Ag. OU Pât.
# 19  Niveau ≥ 2<br>N. régions ≥ 3<br>Ag. ET Pât.
# 20  Niveau ≥ 3<br>N. régions ≥ 3<br>Ag. ET Pât.
# 21  Niveau ≥ 3<br>N. régions ≥ 3<br>Ag. OU Pât.
# 22  Niveau ≥ 1<br>N. régions ≥ 4<br>Ag. ET Pât.
# 23  Niveau ≥ 2<br>N. régions ≥ 3<br>Ag. OU Pât.
# 24  Niveau ≥ 3<br>N. régions ≥ 2<br>Ag. ET Pât.
# 25  Niveau ≥ 4<br>N. régions ≥ 2<br>Ag. ET Pât.
# 26  Niveau ≥ 4<br>N. régions ≥ 1<br>Ag. ET Pât.
# 27  Niveau ≥ 4<br>N. régions ≥ 4<br>Ag. OU Pât.
# 28  Niveau ≥ 3<br>N. régions ≥ 4<br>Ag. OU Pât.
# 29  Niveau ≥ 2<br>N. régions ≥ 4<br>Ag. OU Pât.
# 30  Niveau ≥ 4<br>N. régions ≥ 3<br>Ag. ET Pât.
# 31  Niveau ≥ 4<br>N. régions ≥ 3<br>Ag. OU Pât.
# 32  Niveau ≥ 2<br>N. régions ≥ 3<br>Ag. ET Pât.
# 33  Niveau ≥ 3<br>N. régions ≥ 3<br>Ag. ET Pât.
# 34  Niveau ≥ 3<br>N. régions ≥ 3<br>Ag. OU Pât.
# 35  Niveau ≥ 1<br>N. régions ≥ 4<br>Ag. ET Pât.
# 36  Niveau ≥ 2<br>N. régions ≥ 3<br>Ag. OU Pât.
# 37  Niveau ≥ 3<br>N. régions ≥ 2<br>Ag. ET Pât.
# 38  Niveau ≥ 4<br>N. régions ≥ 2<br>Ag. ET Pât.
# 39  Niveau ≥ 4<br>N. régions ≥ 1<br>Ag. ET Pât.
# 40  Niveau ≥ 4<br>N. régions ≥ 4<br>Ag. OU Pât.

# %%
# this is literally just to make those little boxes on the plot
def plot_grid(x, y, symbol, ax, pitch=0.2):
    grid = np.zeros((2, 2))  # Create a 2x2 grid of empty boxes
    symbol = int(symbol)
    if symbol == 1:
        grid[0, 0] = 1  # Top-left
    elif symbol == 2:
        grid[0, 0] = 1  # Top-left
        grid[1, 1] = 1  # Bottom-right
    elif symbol == 3:
        grid[0, 0] = 1  # Top-left
        grid[1, 1] = 1  # Bottom-right
        grid[0, 1] = 1  # Top-right
    elif symbol == 4:
        grid[0, 0] = 1  # Top-left
        grid[0, 1] = 1  # Top-right
        grid[1, 0] = 1  # Bottom-left
        grid[1, 1] = 1  # Bottom-right

    ax.imshow(
        grid,
        extent=[x - pitch, x + pitch, y - pitch, y + pitch],
        origin="upper",
        cmap="Greys",
        alpha=1,
        vmin=0,
        vmax=1,
    )
    ax.plot(
        [x - pitch, x + pitch], [y - pitch, y - pitch], color="black", lw=0.2
    )  # Top border
    ax.plot(
        [x - pitch, x + pitch], [y + pitch, y + pitch], color="black", lw=0.2
    )  # Bottom border
    ax.plot(
        [x - pitch, x - pitch], [y - pitch, y + pitch], color="black", lw=0.2
    )  # Left border
    ax.plot(
        [x + pitch, x + pitch], [y - pitch, y + pitch], color="black", lw=0.2
    )

# %%
# just to check which data points from the plot correspond to which ASAP triggers
df_asap_v_seas5_rp.sort_values(
    ["rp_com", "rp_asap", "rp_seas5_com", "rp_seas5_ind"], ascending=True
)
# Out:
#       rp_com    rp_asap  rp_seas5_com  rp_seas5_ind  \
# 39  3.125000   4.166667      6.250000      8.333333
# 26  3.125000   4.166667      6.250000     12.500000
# 36  3.125000   5.000000      6.250000      8.333333
# 37  3.125000   5.000000      6.250000      8.333333
# 38  3.125000   5.000000      6.250000      8.333333
# 23  3.125000   5.000000      6.250000     12.500000
# 24  3.125000   5.000000      6.250000     12.500000
# 25  3.125000   5.000000      6.250000     12.500000
# 35  3.125000   6.250000      6.250000      8.333333
# 22  3.125000   6.250000      6.250000     12.500000
# 40  3.125000  25.000000      3.571429      6.250000
# 11  3.571429   3.571429     12.500000     25.000000
# 12  3.571429   3.571429     12.500000     25.000000
# 13  3.571429   3.571429     12.500000     25.000000
# 8   3.571429   4.166667     12.500000     25.000000
# 9   3.571429   4.166667     12.500000     25.000000
# 31  3.571429   8.333333      6.250000      8.333333
# 32  3.571429   8.333333      6.250000      8.333333
# 33  3.571429   8.333333      6.250000      8.333333
# 34  3.571429   8.333333      6.250000      8.333333
# 18  3.571429   8.333333      6.250000     12.500000
# 19  3.571429   8.333333      6.250000     12.500000
# 20  3.571429   8.333333      6.250000     12.500000
# 21  3.571429   8.333333      6.250000     12.500000
# 10  4.166667   4.166667     12.500000     25.000000
# 5   4.166667   5.000000     12.500000     25.000000
# 6   4.166667   5.000000     12.500000     25.000000
# 7   4.166667   5.000000     12.500000     25.000000
# 4   4.166667   6.250000     12.500000     25.000000
# 28  4.166667  12.500000      6.250000      8.333333
# 29  4.166667  12.500000      6.250000      8.333333
# 30  4.166667  12.500000      6.250000      8.333333
# 15  4.166667  12.500000      6.250000     12.500000
# 16  4.166667  12.500000      6.250000     12.500000
# 17  4.166667  12.500000      6.250000     12.500000
# 0   5.000000   8.333333     12.500000     25.000000
# 1   5.000000   8.333333     12.500000     25.000000
# 2   5.000000   8.333333     12.500000     25.000000
# 3   5.000000   8.333333     12.500000     25.000000
# 27  5.000000  25.000000      6.250000      8.333333
# 14  5.000000  25.000000      6.250000     12.500000
#
#                                        asap_col
# 39  Niveau ≥ 4<br>N. régions ≥ 1<br>Ag. ET Pât.
# 26  Niveau ≥ 4<br>N. régions ≥ 1<br>Ag. ET Pât.
# 36  Niveau ≥ 2<br>N. régions ≥ 3<br>Ag. OU Pât.
# 37  Niveau ≥ 3<br>N. régions ≥ 2<br>Ag. ET Pât.
# 38  Niveau ≥ 4<br>N. régions ≥ 2<br>Ag. ET Pât.
# 23  Niveau ≥ 2<br>N. régions ≥ 3<br>Ag. OU Pât.
# 24  Niveau ≥ 3<br>N. régions ≥ 2<br>Ag. ET Pât.
# 25  Niveau ≥ 4<br>N. régions ≥ 2<br>Ag. ET Pât.
# 35  Niveau ≥ 1<br>N. régions ≥ 4<br>Ag. ET Pât.
# 22  Niveau ≥ 1<br>N. régions ≥ 4<br>Ag. ET Pât.
# 40  Niveau ≥ 4<br>N. régions ≥ 4<br>Ag. OU Pât.
# 11  Niveau ≥ 4<br>N. régions ≥ 1<br>Ag. OU Pât.
# 12  Niveau ≥ 2<br>N. régions ≥ 2<br>Ag. ET Pât.
# 13  Niveau ≥ 3<br>N. régions ≥ 1<br>Ag. ET Pât.
# 8   Niveau ≥ 3<br>N. régions ≥ 2<br>Ag. OU Pât.
# 9   Niveau ≥ 4<br>N. régions ≥ 2<br>Ag. OU Pât.
# 31  Niveau ≥ 4<br>N. régions ≥ 3<br>Ag. OU Pât.
# 32  Niveau ≥ 2<br>N. régions ≥ 3<br>Ag. ET Pât.
# 33  Niveau ≥ 3<br>N. régions ≥ 3<br>Ag. ET Pât.
# 34  Niveau ≥ 3<br>N. régions ≥ 3<br>Ag. OU Pât.
# 18  Niveau ≥ 4<br>N. régions ≥ 3<br>Ag. OU Pât.
# 19  Niveau ≥ 2<br>N. régions ≥ 3<br>Ag. ET Pât.
# 20  Niveau ≥ 3<br>N. régions ≥ 3<br>Ag. ET Pât.
# 21  Niveau ≥ 3<br>N. régions ≥ 3<br>Ag. OU Pât.
# 10  Niveau ≥ 4<br>N. régions ≥ 1<br>Ag. ET Pât.
# 5   Niveau ≥ 2<br>N. régions ≥ 3<br>Ag. OU Pât.
# 6   Niveau ≥ 3<br>N. régions ≥ 2<br>Ag. ET Pât.
# 7   Niveau ≥ 4<br>N. régions ≥ 2<br>Ag. ET Pât.
# 4   Niveau ≥ 1<br>N. régions ≥ 4<br>Ag. ET Pât.
# 28  Niveau ≥ 3<br>N. régions ≥ 4<br>Ag. OU Pât.
# 29  Niveau ≥ 2<br>N. régions ≥ 4<br>Ag. OU Pât.
# 30  Niveau ≥ 4<br>N. régions ≥ 3<br>Ag. ET Pât.
# 15  Niveau ≥ 3<br>N. régions ≥ 4<br>Ag. OU Pât.
# 16  Niveau ≥ 2<br>N. régions ≥ 4<br>Ag. OU Pât.
# 17  Niveau ≥ 4<br>N. régions ≥ 3<br>Ag. ET Pât.
# 0   Niveau ≥ 4<br>N. régions ≥ 3<br>Ag. OU Pât.
# 1   Niveau ≥ 2<br>N. régions ≥ 3<br>Ag. ET Pât.
# 2   Niveau ≥ 3<br>N. régions ≥ 3<br>Ag. ET Pât.
# 3   Niveau ≥ 3<br>N. régions ≥ 3<br>Ag. OU Pât.
# 27  Niveau ≥ 4<br>N. régions ≥ 4<br>Ag. OU Pât.
# 14  Niveau ≥ 4<br>N. régions ≥ 4<br>Ag. OU Pât.

# %% [markdown]
# ### Plot combined RP combinations

# %%
fig, ax = plt.subplots(figsize=(8, 8), dpi=200)

colors = ["dodgerblue", "green", "darkorange", "rebeccapurple"]

df_asap_v_seas5_rp_deduplicated = df_asap_v_seas5_rp.sort_values(
    "rp_com", ascending=True
).drop_duplicates(["rp_asap", "rp_seas5_ind"], keep="first")

for (rp_com, group), color in zip(
    df_asap_v_seas5_rp_deduplicated.groupby("rp_com"), colors
):
    group.plot(
        x="rp_seas5_ind",
        y="rp_asap",
        marker=".",
        linewidth=0,
        ax=ax,
        label=f"{rp_com:.1f}",
        color=color,
        markersize=20,
    )
    for _, row in group.iterrows():
        al, minadm1s, crop_range_fr = extract_asap_params(row["asap_col"])
        ax.annotate(
            "&" if crop_range_fr == "ET" else "||",
            (row["rp_seas5_ind"] + 0.35, row["rp_asap"]),
            ha="left",
            va="center",
            fontsize=6,
        )
        plot_grid(
            row["rp_seas5_ind"] + 0.85,
            row["rp_asap"],
            minadm1s,
            ax,
        )
        ax.annotate(
            al + "+",
            (row["rp_seas5_ind"] + 1.1, row["rp_asap"]),
            ha="left",
            va="center",
            fontsize=6,
        )

ax.legend(title="Période de retour\ncombinée (ans)")
ax.set_xlabel("Période de retour individuelle des prévisions (ans)")
ax.set_ylabel("Période de retour des alertes ASAP (ans)")
ax.set_title("Déclencheurs avec période de retour combinée acceptable")

lims = (3, 27)
ax.set_xlim(lims)
ax.set_ylim(lims)

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

# %% [markdown]
# ### Display combined activations

# %%
df_both_yearly
# Out:
#     year  issued_3  issued_7  Niveau ≥ 4<br>N. régions ≥ 4<br>Ag. OU Pât.  \
# 23  2024  0.545455  0.295455                                        False
# 22  2023  0.409091  0.840909                                        False
# 21  2022  0.750000  0.750000                                        False
# 20  2021  0.704545  0.500000                                        False
# 19  2020  0.454545  0.181818                                        False
# 18  2019  0.159091  0.090909                                        False
# 17  2018  0.568182  0.568182                                        False
# 16  2017  0.363636  0.272727                                        False
# 15  2016  0.295455  0.409091                                        False
# 14  2015  0.204545  0.613636                                        False
# 13  2014  0.272727  0.295455                                        False
# 12  2013  0.363636  0.386364                                        False
# 11  2012  0.363636  0.477273                                        False
# 10  2011  0.590909  0.863636                                        False
# 9   2010  0.090909  0.818182                                        False
# 8   2009  0.045455  0.250000                                        False
# 7   2008  0.659091  0.681818                                        False
# 6   2007  0.547727  0.295455                                        False
# 5   2006  0.363636  0.545455                                        False
# 4   2005  0.818182  0.250000                                        False
# 3   2004  0.727273  0.250000                                        False
# 2   2003  0.431818  0.365909                                        False
# 1   2002  0.568182  0.522727                                         True
# 0   2001  0.931818  0.295455                                        False
#
#     Niveau ≥ 3<br>N. régions ≥ 4<br>Ag. OU Pât.  \
# 23                                        False
# 22                                        False
# 21                                        False
# 20                                        False
# 19                                        False
# 18                                        False
# 17                                        False
# 16                                        False
# 15                                        False
# 14                                        False
# 13                                        False
# 12                                        False
# 11                                        False
# 10                                        False
# 9                                         False
# 8                                         False
# 7                                         False
# 6                                         False
# 5                                          True
# 4                                         False
# 3                                         False
# 2                                         False
# 1                                          True
# 0                                         False
#
#     Niveau ≥ 2<br>N. régions ≥ 4<br>Ag. OU Pât.  \
# 23                                        False
# 22                                        False
# 21                                        False
# 20                                        False
# 19                                        False
# 18                                        False
# 17                                        False
# 16                                        False
# 15                                        False
# 14                                        False
# 13                                        False
# 12                                        False
# 11                                        False
# 10                                        False
# 9                                         False
# 8                                         False
# 7                                         False
# 6                                         False
# 5                                          True
# 4                                         False
# 3                                         False
# 2                                         False
# 1                                          True
# 0                                         False
#
#     Niveau ≥ 4<br>N. régions ≥ 3<br>Ag. ET Pât.  \
# 23                                        False
# 22                                        False
# 21                                        False
# 20                                        False
# 19                                        False
# 18                                        False
# 17                                        False
# 16                                        False
# 15                                        False
# 14                                        False
# 13                                        False
# 12                                        False
# 11                                        False
# 10                                         True
# 9                                         False
# 8                                         False
# 7                                         False
# 6                                         False
# 5                                         False
# 4                                         False
# 3                                         False
# 2                                         False
# 1                                          True
# 0                                         False
#
#     Niveau ≥ 4<br>N. régions ≥ 3<br>Ag. OU Pât.  \
# 23                                        False
# 22                                        False
# 21                                        False
# 20                                        False
# 19                                        False
# 18                                        False
# 17                                        False
# 16                                        False
# 15                                        False
# 14                                        False
# 13                                        False
# 12                                        False
# 11                                        False
# 10                                         True
# 9                                         False
# 8                                         False
# 7                                         False
# 6                                         False
# 5                                          True
# 4                                         False
# 3                                         False
# 2                                         False
# 1                                          True
# 0                                         False
#
#     Niveau ≥ 2<br>N. régions ≥ 3<br>Ag. ET Pât.  \
# 23                                        False
# 22                                        False
# 21                                        False
# 20                                        False
# 19                                        False
# 18                                        False
# 17                                        False
# 16                                        False
# 15                                        False
# 14                                        False
# 13                                        False
# 12                                        False
# 11                                        False
# 10                                         True
# 9                                         False
# 8                                         False
# 7                                         False
# 6                                         False
# 5                                          True
# 4                                         False
# 3                                         False
# 2                                         False
# 1                                          True
# 0                                         False
#
#     Niveau ≥ 3<br>N. régions ≥ 3<br>Ag. ET Pât.  ...  \
# 23                                        False  ...
# 22                                        False  ...
# 21                                        False  ...
# 20                                        False  ...
# 19                                        False  ...
# 18                                        False  ...
# 17                                        False  ...
# 16                                        False  ...
# 15                                        False  ...
# 14                                        False  ...
# 13                                        False  ...
# 12                                        False  ...
# 11                                        False  ...
# 10                                         True  ...
# 9                                         False  ...
# 8                                         False  ...
# 7                                         False  ...
# 6                                         False  ...
# 5                                          True  ...
# 4                                         False  ...
# 3                                         False  ...
# 2                                         False  ...
# 1                                          True  ...
# 0                                         False  ...
#
#     Niveau ≥ 1<br>N. régions ≥ 2<br>Ag. ET Pât.  \
# 23                                         True
# 22                                        False
# 21                                        False
# 20                                         True
# 19                                        False
# 18                                         True
# 17                                        False
# 16                                         True
# 15                                        False
# 14                                         True
# 13                                         True
# 12                                        False
# 11                                        False
# 10                                         True
# 9                                          True
# 8                                          True
# 7                                          True
# 6                                          True
# 5                                          True
# 4                                          True
# 3                                          True
# 2                                         False
# 1                                          True
# 0                                          True
#
#     Niveau ≥ 1<br>N. régions ≥ 2<br>Ag. OU Pât.  \
# 23                                         True
# 22                                        False
# 21                                        False
# 20                                         True
# 19                                         True
# 18                                         True
# 17                                        False
# 16                                         True
# 15                                        False
# 14                                         True
# 13                                         True
# 12                                        False
# 11                                        False
# 10                                         True
# 9                                          True
# 8                                          True
# 7                                          True
# 6                                          True
# 5                                          True
# 4                                          True
# 3                                          True
# 2                                         False
# 1                                          True
# 0                                          True
#
#     Niveau ≥ 1<br>N. régions ≥ 1<br>Ag. ET Pât.  \
# 23                                         True
# 22                                        False
# 21                                        False
# 20                                         True
# 19                                         True
# 18                                         True
# 17                                        False
# 16                                         True
# 15                                        False
# 14                                         True
# 13                                         True
# 12                                         True
# 11                                        False
# 10                                         True
# 9                                          True
# 8                                          True
# 7                                          True
# 6                                          True
# 5                                          True
# 4                                          True
# 3                                          True
# 2                                         False
# 1                                          True
# 0                                          True
#
#     Niveau ≥ 1<br>N. régions ≥ 1<br>Ag. OU Pât.  issued_3_bool  issued_7_bool  \
# 23                                         True          False          False
# 22                                         True          False          False
# 21                                        False          False          False
# 20                                         True          False          False
# 19                                         True          False          False
# 18                                         True          False          False
# 17                                        False          False          False
# 16                                         True          False          False
# 15                                         True          False          False
# 14                                         True          False          False
# 13                                         True          False          False
# 12                                         True          False          False
# 11                                        False          False          False
# 10                                         True          False          False
# 9                                          True          False          False
# 8                                          True          False          False
# 7                                          True          False          False
# 6                                          True          False          False
# 5                                          True          False          False
# 4                                          True          False          False
# 3                                          True          False          False
# 2                                          True          False          False
# 1                                          True          False          False
# 0                                          True          False          False
#
#     issued_3_rank  issued_3_rp  issued_7_rank  issued_7_rp
# 23           14.0     1.785714            8.5     2.941176
# 22           11.0     2.272727           23.0     1.086957
# 21           22.0     1.136364           21.0     1.190476
# 20           20.0     1.250000           15.0     1.666667
# 19           13.0     1.923077            2.0    12.500000
# 18            3.0     8.333333            1.0    25.000000
# 17           16.5     1.515152           18.0     1.388889
# 16            8.5     2.941176            6.0     4.166667
# 15            6.0     4.166667           13.0     1.923077
# 14            4.0     6.250000           19.0     1.315789
# 13            5.0     5.000000            8.5     2.941176
# 12            8.5     2.941176           12.0     2.083333
# 11            8.5     2.941176           14.0     1.785714
# 10           18.0     1.388889           24.0     1.041667
# 9             2.0    12.500000           22.0     1.136364
# 8             1.0    25.000000            4.0     6.250000
# 7            19.0     1.315789           20.0     1.250000
# 6            15.0     1.666667            8.5     2.941176
# 5             8.5     2.941176           17.0     1.470588
# 4            23.0     1.086957            4.0     6.250000
# 3            21.0     1.190476            4.0     6.250000
# 2            12.0     2.083333           11.0     2.272727
# 1            16.5     1.515152           16.0     1.562500
# 0            24.0     1.041667            8.5     2.941176
#
# [24 rows x 38 columns]

# %%
def display_combined_activations(asap_col, rp_seas5_ind):
    df_disp = df_both_yearly.rename(columns={"year": "Année"}).set_index(
        "Année"
    )
    cols = []
    for mo in [3, 7]:
        col = f"Prévisions de<br>{FRENCH_MONTHS[calendar.month_abbr[mo]]}"
        df_disp[col] = df_disp[f"issued_{mo}_rp"] > rp_seas5_ind
        print(f"fcast {mo} rp:")
        print((len(df_disp) + 1) / df_disp[col].sum())
        print()
        cols.append(col)
    df_disp = df_disp[cols + [asap_col]]
    print(f"fcast combined rp:")
    print((len(df_disp) + 1) / df_disp[cols].any(axis=1).sum())
    print()
    print("asap rp:")
    print((len(df_disp) + 1) / df_disp[asap_col].sum())
    print()
    print("combined rp:")
    print((len(df_disp) + 1) / df_disp.any(axis=1).sum())
    display(
        df_disp.replace(
            {True: "Activation", False: "Pas d'activation"}
        ).style.map(highlight_true)
    )

# %%
asap_col = ASAP_COL.format(al=4, minadm1s=1, crop_range_fr="ET")
display_combined_activations(asap_col, 8)
# Out:
# fcast 3 rp:
# 8.333333333333334
#
# fcast 7 rp:
# 12.5
#
# fcast combined rp:
# 6.25
# fcast combined prob:
# 0.16
#
# asap rp:
# 4.166666666666667
# asap prob:
# 0.24
#
# combined rp:
# 3.125
# combined prob:
# 0.32
# <style type="text/css">
# #T_fc1fe_row0_col0, #T_fc1fe_row0_col1, #T_fc1fe_row0_col2, #T_fc1fe_row1_col0, #T_fc1fe_row1_col1, #T_fc1fe_row1_col2, #T_fc1fe_row2_col0, #T_fc1fe_row2_col1, #T_fc1fe_row2_col2, #T_fc1fe_row3_col0, #T_fc1fe_row3_col1, #T_fc1fe_row3_col2, #T_fc1fe_row4_col0, #T_fc1fe_row4_col2, #T_fc1fe_row6_col0, #T_fc1fe_row6_col1, #T_fc1fe_row6_col2, #T_fc1fe_row7_col0, #T_fc1fe_row7_col1, #T_fc1fe_row7_col2, #T_fc1fe_row8_col0, #T_fc1fe_row8_col1, #T_fc1fe_row8_col2, #T_fc1fe_row9_col0, #T_fc1fe_row9_col1, #T_fc1fe_row9_col2, #T_fc1fe_row10_col0, #T_fc1fe_row10_col1, #T_fc1fe_row10_col2, #T_fc1fe_row11_col0, #T_fc1fe_row11_col1, #T_fc1fe_row11_col2, #T_fc1fe_row12_col0, #T_fc1fe_row12_col1, #T_fc1fe_row12_col2, #T_fc1fe_row13_col0, #T_fc1fe_row13_col1, #T_fc1fe_row14_col1, #T_fc1fe_row14_col2, #T_fc1fe_row15_col1, #T_fc1fe_row16_col0, #T_fc1fe_row16_col1, #T_fc1fe_row16_col2, #T_fc1fe_row17_col0, #T_fc1fe_row17_col1, #T_fc1fe_row17_col2, #T_fc1fe_row18_col0, #T_fc1fe_row18_col1, #T_fc1fe_row19_col0, #T_fc1fe_row19_col1, #T_fc1fe_row19_col2, #T_fc1fe_row20_col0, #T_fc1fe_row20_col1, #T_fc1fe_row21_col0, #T_fc1fe_row21_col1, #T_fc1fe_row21_col2, #T_fc1fe_row22_col0, #T_fc1fe_row22_col1, #T_fc1fe_row23_col0, #T_fc1fe_row23_col1, #T_fc1fe_row23_col2 {
#   color: lightgrey;
# }
# #T_fc1fe_row4_col1, #T_fc1fe_row5_col0, #T_fc1fe_row5_col1, #T_fc1fe_row5_col2, #T_fc1fe_row13_col2, #T_fc1fe_row14_col0, #T_fc1fe_row15_col0, #T_fc1fe_row15_col2, #T_fc1fe_row18_col2, #T_fc1fe_row20_col2, #T_fc1fe_row22_col2 {
#   background-color: crimson;
#   color: white;
# }
# </style>
# <table id="T_fc1fe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc1fe_level0_col0" class="col_heading level0 col0" >Prévisions de<br>mars</th>
#       <th id="T_fc1fe_level0_col1" class="col_heading level0 col1" >Prévisions de<br>juil.</th>
#       <th id="T_fc1fe_level0_col2" class="col_heading level0 col2" >Niveau ≥ 4<br>N. régions ≥ 1<br>Ag. ET Pât.</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Année</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc1fe_level0_row0" class="row_heading level0 row0" >2024</th>
#       <td id="T_fc1fe_row0_col0" class="data row0 col0" >Pas d'activation</td>
#       <td id="T_fc1fe_row0_col1" class="data row0 col1" >Pas d'activation</td>
#       <td id="T_fc1fe_row0_col2" class="data row0 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_fc1fe_level0_row1" class="row_heading level0 row1" >2023</th>
#       <td id="T_fc1fe_row1_col0" class="data row1 col0" >Pas d'activation</td>
#       <td id="T_fc1fe_row1_col1" class="data row1 col1" >Pas d'activation</td>
#       <td id="T_fc1fe_row1_col2" class="data row1 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_fc1fe_level0_row2" class="row_heading level0 row2" >2022</th>
#       <td id="T_fc1fe_row2_col0" class="data row2 col0" >Pas d'activation</td>
#       <td id="T_fc1fe_row2_col1" class="data row2 col1" >Pas d'activation</td>
#       <td id="T_fc1fe_row2_col2" class="data row2 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_fc1fe_level0_row3" class="row_heading level0 row3" >2021</th>
#       <td id="T_fc1fe_row3_col0" class="data row3 col0" >Pas d'activation</td>
#       <td id="T_fc1fe_row3_col1" class="data row3 col1" >Pas d'activation</td>
#       <td id="T_fc1fe_row3_col2" class="data row3 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_fc1fe_level0_row4" class="row_heading level0 row4" >2020</th>
#       <td id="T_fc1fe_row4_col0" class="data row4 col0" >Pas d'activation</td>
#       <td id="T_fc1fe_row4_col1" class="data row4 col1" >Activation</td>
#       <td id="T_fc1fe_row4_col2" class="data row4 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_fc1fe_level0_row5" class="row_heading level0 row5" >2019</th>
#       <td id="T_fc1fe_row5_col0" class="data row5 col0" >Activation</td>
#       <td id="T_fc1fe_row5_col1" class="data row5 col1" >Activation</td>
#       <td id="T_fc1fe_row5_col2" class="data row5 col2" >Activation</td>
#     </tr>
#     <tr>
#       <th id="T_fc1fe_level0_row6" class="row_heading level0 row6" >2018</th>
#       <td id="T_fc1fe_row6_col0" class="data row6 col0" >Pas d'activation</td>
#       <td id="T_fc1fe_row6_col1" class="data row6 col1" >Pas d'activation</td>
#       <td id="T_fc1fe_row6_col2" class="data row6 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_fc1fe_level0_row7" class="row_heading level0 row7" >2017</th>
#       <td id="T_fc1fe_row7_col0" class="data row7 col0" >Pas d'activation</td>
#       <td id="T_fc1fe_row7_col1" class="data row7 col1" >Pas d'activation</td>
#       <td id="T_fc1fe_row7_col2" class="data row7 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_fc1fe_level0_row8" class="row_heading level0 row8" >2016</th>
#       <td id="T_fc1fe_row8_col0" class="data row8 col0" >Pas d'activation</td>
#       <td id="T_fc1fe_row8_col1" class="data row8 col1" >Pas d'activation</td>
#       <td id="T_fc1fe_row8_col2" class="data row8 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_fc1fe_level0_row9" class="row_heading level0 row9" >2015</th>
#       <td id="T_fc1fe_row9_col0" class="data row9 col0" >Pas d'activation</td>
#       <td id="T_fc1fe_row9_col1" class="data row9 col1" >Pas d'activation</td>
#       <td id="T_fc1fe_row9_col2" class="data row9 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_fc1fe_level0_row10" class="row_heading level0 row10" >2014</th>
#       <td id="T_fc1fe_row10_col0" class="data row10 col0" >Pas d'activation</td>
#       <td id="T_fc1fe_row10_col1" class="data row10 col1" >Pas d'activation</td>
#       <td id="T_fc1fe_row10_col2" class="data row10 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_fc1fe_level0_row11" class="row_heading level0 row11" >2013</th>
#       <td id="T_fc1fe_row11_col0" class="data row11 col0" >Pas d'activation</td>
#       <td id="T_fc1fe_row11_col1" class="data row11 col1" >Pas d'activation</td>
#       <td id="T_fc1fe_row11_col2" class="data row11 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_fc1fe_level0_row12" class="row_heading level0 row12" >2012</th>
#       <td id="T_fc1fe_row12_col0" class="data row12 col0" >Pas d'activation</td>
#       <td id="T_fc1fe_row12_col1" class="data row12 col1" >Pas d'activation</td>
#       <td id="T_fc1fe_row12_col2" class="data row12 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_fc1fe_level0_row13" class="row_heading level0 row13" >2011</th>
#       <td id="T_fc1fe_row13_col0" class="data row13 col0" >Pas d'activation</td>
#       <td id="T_fc1fe_row13_col1" class="data row13 col1" >Pas d'activation</td>
#       <td id="T_fc1fe_row13_col2" class="data row13 col2" >Activation</td>
#     </tr>
#     <tr>
#       <th id="T_fc1fe_level0_row14" class="row_heading level0 row14" >2010</th>
#       <td id="T_fc1fe_row14_col0" class="data row14 col0" >Activation</td>
#       <td id="T_fc1fe_row14_col1" class="data row14 col1" >Pas d'activation</td>
#       <td id="T_fc1fe_row14_col2" class="data row14 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_fc1fe_level0_row15" class="row_heading level0 row15" >2009</th>
#       <td id="T_fc1fe_row15_col0" class="data row15 col0" >Activation</td>
#       <td id="T_fc1fe_row15_col1" class="data row15 col1" >Pas d'activation</td>
#       <td id="T_fc1fe_row15_col2" class="data row15 col2" >Activation</td>
#     </tr>
#     <tr>
#       <th id="T_fc1fe_level0_row16" class="row_heading level0 row16" >2008</th>
#       <td id="T_fc1fe_row16_col0" class="data row16 col0" >Pas d'activation</td>
#       <td id="T_fc1fe_row16_col1" class="data row16 col1" >Pas d'activation</td>
#       <td id="T_fc1fe_row16_col2" class="data row16 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_fc1fe_level0_row17" class="row_heading level0 row17" >2007</th>
#       <td id="T_fc1fe_r

# %%
asap_col = ASAP_COL.format(al=4, minadm1s=1, crop_range_fr="ET")
display_combined_activations(asap_col, 7)
# Out:
# fcast 3 rp:
# 8.333333333333334
#
# fcast 7 rp:
# 12.5
#
# fcast combined rp:
# 6.25
# fcast combined prob:
# 0.16
#
# asap rp:
# 4.166666666666667
# asap prob:
# 0.24
#
# combined rp:
# 3.125
# combined prob:
# 0.32
# <style type="text/css">
# #T_0d132_row0_col0, #T_0d132_row0_col1, #T_0d132_row0_col2, #T_0d132_row1_col0, #T_0d132_row1_col1, #T_0d132_row1_col2, #T_0d132_row2_col0, #T_0d132_row2_col1, #T_0d132_row2_col2, #T_0d132_row3_col0, #T_0d132_row3_col1, #T_0d132_row3_col2, #T_0d132_row4_col0, #T_0d132_row4_col2, #T_0d132_row6_col0, #T_0d132_row6_col1, #T_0d132_row6_col2, #T_0d132_row7_col0, #T_0d132_row7_col1, #T_0d132_row7_col2, #T_0d132_row8_col0, #T_0d132_row8_col1, #T_0d132_row8_col2, #T_0d132_row9_col0, #T_0d132_row9_col1, #T_0d132_row9_col2, #T_0d132_row10_col0, #T_0d132_row10_col1, #T_0d132_row10_col2, #T_0d132_row11_col0, #T_0d132_row11_col1, #T_0d132_row11_col2, #T_0d132_row12_col0, #T_0d132_row12_col1, #T_0d132_row12_col2, #T_0d132_row13_col0, #T_0d132_row13_col1, #T_0d132_row14_col1, #T_0d132_row14_col2, #T_0d132_row15_col1, #T_0d132_row16_col0, #T_0d132_row16_col1, #T_0d132_row16_col2, #T_0d132_row17_col0, #T_0d132_row17_col1, #T_0d132_row17_col2, #T_0d132_row18_col0, #T_0d132_row18_col1, #T_0d132_row19_col0, #T_0d132_row19_col1, #T_0d132_row19_col2, #T_0d132_row20_col0, #T_0d132_row20_col1, #T_0d132_row21_col0, #T_0d132_row21_col1, #T_0d132_row21_col2, #T_0d132_row22_col0, #T_0d132_row22_col1, #T_0d132_row23_col0, #T_0d132_row23_col1, #T_0d132_row23_col2 {
#   color: lightgrey;
# }
# #T_0d132_row4_col1, #T_0d132_row5_col0, #T_0d132_row5_col1, #T_0d132_row5_col2, #T_0d132_row13_col2, #T_0d132_row14_col0, #T_0d132_row15_col0, #T_0d132_row15_col2, #T_0d132_row18_col2, #T_0d132_row20_col2, #T_0d132_row22_col2 {
#   background-color: crimson;
#   color: white;
# }
# </style>
# <table id="T_0d132">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d132_level0_col0" class="col_heading level0 col0" >Prévisions de<br>mars</th>
#       <th id="T_0d132_level0_col1" class="col_heading level0 col1" >Prévisions de<br>juil.</th>
#       <th id="T_0d132_level0_col2" class="col_heading level0 col2" >Niveau ≥ 4<br>N. régions ≥ 1<br>Ag. ET Pât.</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Année</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d132_level0_row0" class="row_heading level0 row0" >2024</th>
#       <td id="T_0d132_row0_col0" class="data row0 col0" >Pas d'activation</td>
#       <td id="T_0d132_row0_col1" class="data row0 col1" >Pas d'activation</td>
#       <td id="T_0d132_row0_col2" class="data row0 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_0d132_level0_row1" class="row_heading level0 row1" >2023</th>
#       <td id="T_0d132_row1_col0" class="data row1 col0" >Pas d'activation</td>
#       <td id="T_0d132_row1_col1" class="data row1 col1" >Pas d'activation</td>
#       <td id="T_0d132_row1_col2" class="data row1 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_0d132_level0_row2" class="row_heading level0 row2" >2022</th>
#       <td id="T_0d132_row2_col0" class="data row2 col0" >Pas d'activation</td>
#       <td id="T_0d132_row2_col1" class="data row2 col1" >Pas d'activation</td>
#       <td id="T_0d132_row2_col2" class="data row2 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_0d132_level0_row3" class="row_heading level0 row3" >2021</th>
#       <td id="T_0d132_row3_col0" class="data row3 col0" >Pas d'activation</td>
#       <td id="T_0d132_row3_col1" class="data row3 col1" >Pas d'activation</td>
#       <td id="T_0d132_row3_col2" class="data row3 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_0d132_level0_row4" class="row_heading level0 row4" >2020</th>
#       <td id="T_0d132_row4_col0" class="data row4 col0" >Pas d'activation</td>
#       <td id="T_0d132_row4_col1" class="data row4 col1" >Activation</td>
#       <td id="T_0d132_row4_col2" class="data row4 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_0d132_level0_row5" class="row_heading level0 row5" >2019</th>
#       <td id="T_0d132_row5_col0" class="data row5 col0" >Activation</td>
#       <td id="T_0d132_row5_col1" class="data row5 col1" >Activation</td>
#       <td id="T_0d132_row5_col2" class="data row5 col2" >Activation</td>
#     </tr>
#     <tr>
#       <th id="T_0d132_level0_row6" class="row_heading level0 row6" >2018</th>
#       <td id="T_0d132_row6_col0" class="data row6 col0" >Pas d'activation</td>
#       <td id="T_0d132_row6_col1" class="data row6 col1" >Pas d'activation</td>
#       <td id="T_0d132_row6_col2" class="data row6 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_0d132_level0_row7" class="row_heading level0 row7" >2017</th>
#       <td id="T_0d132_row7_col0" class="data row7 col0" >Pas d'activation</td>
#       <td id="T_0d132_row7_col1" class="data row7 col1" >Pas d'activation</td>
#       <td id="T_0d132_row7_col2" class="data row7 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_0d132_level0_row8" class="row_heading level0 row8" >2016</th>
#       <td id="T_0d132_row8_col0" class="data row8 col0" >Pas d'activation</td>
#       <td id="T_0d132_row8_col1" class="data row8 col1" >Pas d'activation</td>
#       <td id="T_0d132_row8_col2" class="data row8 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_0d132_level0_row9" class="row_heading level0 row9" >2015</th>
#       <td id="T_0d132_row9_col0" class="data row9 col0" >Pas d'activation</td>
#       <td id="T_0d132_row9_col1" class="data row9 col1" >Pas d'activation</td>
#       <td id="T_0d132_row9_col2" class="data row9 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_0d132_level0_row10" class="row_heading level0 row10" >2014</th>
#       <td id="T_0d132_row10_col0" class="data row10 col0" >Pas d'activation</td>
#       <td id="T_0d132_row10_col1" class="data row10 col1" >Pas d'activation</td>
#       <td id="T_0d132_row10_col2" class="data row10 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_0d132_level0_row11" class="row_heading level0 row11" >2013</th>
#       <td id="T_0d132_row11_col0" class="data row11 col0" >Pas d'activation</td>
#       <td id="T_0d132_row11_col1" class="data row11 col1" >Pas d'activation</td>
#       <td id="T_0d132_row11_col2" class="data row11 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_0d132_level0_row12" class="row_heading level0 row12" >2012</th>
#       <td id="T_0d132_row12_col0" class="data row12 col0" >Pas d'activation</td>
#       <td id="T_0d132_row12_col1" class="data row12 col1" >Pas d'activation</td>
#       <td id="T_0d132_row12_col2" class="data row12 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_0d132_level0_row13" class="row_heading level0 row13" >2011</th>
#       <td id="T_0d132_row13_col0" class="data row13 col0" >Pas d'activation</td>
#       <td id="T_0d132_row13_col1" class="data row13 col1" >Pas d'activation</td>
#       <td id="T_0d132_row13_col2" class="data row13 col2" >Activation</td>
#     </tr>
#     <tr>
#       <th id="T_0d132_level0_row14" class="row_heading level0 row14" >2010</th>
#       <td id="T_0d132_row14_col0" class="data row14 col0" >Activation</td>
#       <td id="T_0d132_row14_col1" class="data row14 col1" >Pas d'activation</td>
#       <td id="T_0d132_row14_col2" class="data row14 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_0d132_level0_row15" class="row_heading level0 row15" >2009</th>
#       <td id="T_0d132_row15_col0" class="data row15 col0" >Activation</td>
#       <td id="T_0d132_row15_col1" class="data row15 col1" >Pas d'activation</td>
#       <td id="T_0d132_row15_col2" class="data row15 col2" >Activation</td>
#     </tr>
#     <tr>
#       <th id="T_0d132_level0_row16" class="row_heading level0 row16" >2008</th>
#       <td id="T_0d132_row16_col0" class="data row16 col0" >Pas d'activation</td>
#       <td id="T_0d132_row16_col1" class="data row16 col1" >Pas d'activation</td>
#       <td id="T_0d132_row16_col2" class="data row16 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_0d132_level0_row17" class="row_heading level0 row17" >2007</th>
#       <td id="T_0d132_r

# %%
asap_col = ASAP_COL.format(al=4, minadm1s=3, crop_range_fr="ET")
display_combined_activations(asap_col, 5)
# Out:
# fcast 3 rp:
# 6.25
#
# fcast 7 rp:
# 5.0
#
# fcast combined rp:
# 3.5714285714285716
#
# asap rp:
# 12.5
#
# combined rp:
# 2.7777777777777777
# <style type="text/css">
# #T_e9833_row0_col0, #T_e9833_row0_col1, #T_e9833_row0_col2, #T_e9833_row1_col0, #T_e9833_row1_col1, #T_e9833_row1_col2, #T_e9833_row2_col0, #T_e9833_row2_col1, #T_e9833_row2_col2, #T_e9833_row3_col0, #T_e9833_row3_col1, #T_e9833_row3_col2, #T_e9833_row4_col0, #T_e9833_row4_col2, #T_e9833_row5_col2, #T_e9833_row6_col0, #T_e9833_row6_col1, #T_e9833_row6_col2, #T_e9833_row7_col0, #T_e9833_row7_col1, #T_e9833_row7_col2, #T_e9833_row8_col0, #T_e9833_row8_col1, #T_e9833_row8_col2, #T_e9833_row9_col1, #T_e9833_row9_col2, #T_e9833_row10_col0, #T_e9833_row10_col1, #T_e9833_row10_col2, #T_e9833_row11_col0, #T_e9833_row11_col1, #T_e9833_row11_col2, #T_e9833_row12_col0, #T_e9833_row12_col1, #T_e9833_row12_col2, #T_e9833_row13_col0, #T_e9833_row13_col1, #T_e9833_row14_col1, #T_e9833_row14_col2, #T_e9833_row15_col2, #T_e9833_row16_col0, #T_e9833_row16_col1, #T_e9833_row16_col2, #T_e9833_row17_col0, #T_e9833_row17_col1, #T_e9833_row17_col2, #T_e9833_row18_col0, #T_e9833_row18_col1, #T_e9833_row18_col2, #T_e9833_row19_col0, #T_e9833_row19_col2, #T_e9833_row20_col0, #T_e9833_row20_col2, #T_e9833_row21_col0, #T_e9833_row21_col1, #T_e9833_row21_col2, #T_e9833_row22_col0, #T_e9833_row22_col1, #T_e9833_row23_col0, #T_e9833_row23_col1, #T_e9833_row23_col2 {
#   color: lightgrey;
# }
# #T_e9833_row4_col1, #T_e9833_row5_col0, #T_e9833_row5_col1, #T_e9833_row9_col0, #T_e9833_row13_col2, #T_e9833_row14_col0, #T_e9833_row15_col0, #T_e9833_row15_col1, #T_e9833_row19_col1, #T_e9833_row20_col1, #T_e9833_row22_col2 {
#   background-color: crimson;
#   color: white;
# }
# </style>
# <table id="T_e9833">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9833_level0_col0" class="col_heading level0 col0" >Prévisions de<br>mars</th>
#       <th id="T_e9833_level0_col1" class="col_heading level0 col1" >Prévisions de<br>juil.</th>
#       <th id="T_e9833_level0_col2" class="col_heading level0 col2" >Niveau ≥ 4<br>N. régions ≥ 3<br>Ag. ET Pât.</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Année</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9833_level0_row0" class="row_heading level0 row0" >2024</th>
#       <td id="T_e9833_row0_col0" class="data row0 col0" >Pas d'activation</td>
#       <td id="T_e9833_row0_col1" class="data row0 col1" >Pas d'activation</td>
#       <td id="T_e9833_row0_col2" class="data row0 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_e9833_level0_row1" class="row_heading level0 row1" >2023</th>
#       <td id="T_e9833_row1_col0" class="data row1 col0" >Pas d'activation</td>
#       <td id="T_e9833_row1_col1" class="data row1 col1" >Pas d'activation</td>
#       <td id="T_e9833_row1_col2" class="data row1 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_e9833_level0_row2" class="row_heading level0 row2" >2022</th>
#       <td id="T_e9833_row2_col0" class="data row2 col0" >Pas d'activation</td>
#       <td id="T_e9833_row2_col1" class="data row2 col1" >Pas d'activation</td>
#       <td id="T_e9833_row2_col2" class="data row2 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_e9833_level0_row3" class="row_heading level0 row3" >2021</th>
#       <td id="T_e9833_row3_col0" class="data row3 col0" >Pas d'activation</td>
#       <td id="T_e9833_row3_col1" class="data row3 col1" >Pas d'activation</td>
#       <td id="T_e9833_row3_col2" class="data row3 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_e9833_level0_row4" class="row_heading level0 row4" >2020</th>
#       <td id="T_e9833_row4_col0" class="data row4 col0" >Pas d'activation</td>
#       <td id="T_e9833_row4_col1" class="data row4 col1" >Activation</td>
#       <td id="T_e9833_row4_col2" class="data row4 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_e9833_level0_row5" class="row_heading level0 row5" >2019</th>
#       <td id="T_e9833_row5_col0" class="data row5 col0" >Activation</td>
#       <td id="T_e9833_row5_col1" class="data row5 col1" >Activation</td>
#       <td id="T_e9833_row5_col2" class="data row5 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_e9833_level0_row6" class="row_heading level0 row6" >2018</th>
#       <td id="T_e9833_row6_col0" class="data row6 col0" >Pas d'activation</td>
#       <td id="T_e9833_row6_col1" class="data row6 col1" >Pas d'activation</td>
#       <td id="T_e9833_row6_col2" class="data row6 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_e9833_level0_row7" class="row_heading level0 row7" >2017</th>
#       <td id="T_e9833_row7_col0" class="data row7 col0" >Pas d'activation</td>
#       <td id="T_e9833_row7_col1" class="data row7 col1" >Pas d'activation</td>
#       <td id="T_e9833_row7_col2" class="data row7 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_e9833_level0_row8" class="row_heading level0 row8" >2016</th>
#       <td id="T_e9833_row8_col0" class="data row8 col0" >Pas d'activation</td>
#       <td id="T_e9833_row8_col1" class="data row8 col1" >Pas d'activation</td>
#       <td id="T_e9833_row8_col2" class="data row8 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_e9833_level0_row9" class="row_heading level0 row9" >2015</th>
#       <td id="T_e9833_row9_col0" class="data row9 col0" >Activation</td>
#       <td id="T_e9833_row9_col1" class="data row9 col1" >Pas d'activation</td>
#       <td id="T_e9833_row9_col2" class="data row9 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_e9833_level0_row10" class="row_heading level0 row10" >2014</th>
#       <td id="T_e9833_row10_col0" class="data row10 col0" >Pas d'activation</td>
#       <td id="T_e9833_row10_col1" class="data row10 col1" >Pas d'activation</td>
#       <td id="T_e9833_row10_col2" class="data row10 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_e9833_level0_row11" class="row_heading level0 row11" >2013</th>
#       <td id="T_e9833_row11_col0" class="data row11 col0" >Pas d'activation</td>
#       <td id="T_e9833_row11_col1" class="data row11 col1" >Pas d'activation</td>
#       <td id="T_e9833_row11_col2" class="data row11 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_e9833_level0_row12" class="row_heading level0 row12" >2012</th>
#       <td id="T_e9833_row12_col0" class="data row12 col0" >Pas d'activation</td>
#       <td id="T_e9833_row12_col1" class="data row12 col1" >Pas d'activation</td>
#       <td id="T_e9833_row12_col2" class="data row12 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_e9833_level0_row13" class="row_heading level0 row13" >2011</th>
#       <td id="T_e9833_row13_col0" class="data row13 col0" >Pas d'activation</td>
#       <td id="T_e9833_row13_col1" class="data row13 col1" >Pas d'activation</td>
#       <td id="T_e9833_row13_col2" class="data row13 col2" >Activation</td>
#     </tr>
#     <tr>
#       <th id="T_e9833_level0_row14" class="row_heading level0 row14" >2010</th>
#       <td id="T_e9833_row14_col0" class="data row14 col0" >Activation</td>
#       <td id="T_e9833_row14_col1" class="data row14 col1" >Pas d'activation</td>
#       <td id="T_e9833_row14_col2" class="data row14 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_e9833_level0_row15" class="row_heading level0 row15" >2009</th>
#       <td id="T_e9833_row15_col0" class="data row15 col0" >Activation</td>
#       <td id="T_e9833_row15_col1" class="data row15 col1" >Activation</td>
#       <td id="T_e9833_row15_col2" class="data row15 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_e9833_level0_row16" class="row_heading level0 row16" >2008</th>
#       <td id="T_e9833_row16_col0" class="data row16 col0" >Pas d'activation</td>
#       <td id="T_e9833_row16_col1" class="data row16 col1" >Pas d'activation</td>
#       <td id="T_e9833_row16_col2" class="data row16 col2" >Pas d'activation</td>
#     </tr>
#     <tr>
#       <th id="T_e9833_level0_row17" class="row_heading level0 row17" >2007</th>
#       <td id="T_e9833_r
